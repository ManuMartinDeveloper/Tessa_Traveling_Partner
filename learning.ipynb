# %% [markdown]
# ## Test the amadeus api client object

# %%
from amadeus_api_client import amadeus_api_client_object as amadeus_client
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
find_hotels_in_city_result = amadeus_client.find_hotels_in_city("BLR")
find_one_way_flights_result1 = amadeus_client.find_one_way_flights("BLR", "BOM", "2025-10-28", number_of_adults=1, number_of_children=0, nonstop=True, max_results=10)
find_one_way_flights_result2 = amadeus_client.find_one_way_flights("BLR", "COK", "2025-10-25") #
find_hotels_by_area_result = amadeus_client.find_hotels_by_area(latitude= "12.9337799", longitude= "77.6051611", radius= 3)
find_hotels_by_area_result1 = amadeus_client.find_hotels_by_area(12.9337799,77.6051611)
# Out:
# 🏨 Searching for hotels in city: BLR
# ✈️  Searching for flights: BLR -> BOM on 2025-10-28
# ✈️  Searching for flights: BLR -> COK on 2025-10-25
# 🏨 Searching for hotels near lat:12.9337799, lon:77.6051611 within a 3KM radius.
# 🏨 Searching for hotels near lat:12.9337799, lon:77.6051611 within a 2KM radius.

# %%
print(find_hotels_in_city_result,
find_one_way_flights_result1,
find_one_way_flights_result2,
find_hotels_by_area_result,
find_hotels_by_area_result1, sep="\n\n")
# Out:
# [{'chainCode': 'WV', 'iataCode': 'BLR', 'dupeId': 700172702, 'name': 'CITRUS BENGALURU', 'hotelId': 'WVBLR273', 'geoCode': {'latitude': 12.92506, 'longitude': 77.67514}, 'address': {'countryCode': 'IN', 'postalCode': '560103', 'cityName': 'BENGALURU', 'lines': ['80 02 MARATHAHALLI SARJAPUR', 'BELLANDUR']}, 'masterChainCode': 'TC', 'lastUpdate': '2025-06-03T10:18:08'}, {'chainCode': 'MC', 'iataCode': 'BLR', 'dupeId': 700191294, 'name': 'BENGALURU MARRIOTT WHITEFIELD', 'hotelId': 'MCBLRWFM', 'geoCode': {'latitude': 12.98051, 'longitude': 77.72784}, 'address': {'countryCode': 'IN', 'postalCode': '560066', 'cityName': 'BENGALURU', 'lines': ['8TH ROAD PLOT NO 75 EPIP AREA']}, 'masterChainCode': 'EM', 'lastUpdate': '2025-06-03T10:19:13'}, {'chainCode': 'ON', 'iataCode': 'BLR', 'dupeId': 700053475, 'name': 'AJ INTERNATIONAL', 'hotelId': 'ONBLRAJI', 'geoCode': {'latitude': 12.98187, 'longitude': 77.60414}, 'address': {'countryCode': 'IN', 'postalCode': '560001', 'cityName': 'BANGALORE', 'lines': ['15/1 BOWRING HOSPITAL ROAD']}, 'lastUpdate': '2025-06-03T10:21:53'}, {'chainCode': 'TJ', 'iataCode': 'BLR', 'dupeId': 700120479, 'name': 'THE GATEWAY HOTEL KM ROAD', 'hotelId': 'TJBLRTGR', 'geoCode': {'latitude': 13.33653, 'longitude': 75.81744}, 'address': {'countryCode': 'IN', 'postalCode': '577102', 'cityName': 'CHIKMAGALUR', 'lines': ['K M ROAD, OPP. PAVITRA VANNA', 'JYOTHINAGAR']}, 'lastUpdate': '2025-06-03T10:17:49'}, {'chainCode': 'YX', 'iataCode': 'BLR', 'dupeId': 700095215, 'name': 'JUSTA THE RESIDENCE INDIRANAGA', 'hotelId': 'YXBLRJRI', 'geoCode': {'latitude': 12.97096, 'longitude': 77.64062}, 'address': {'countryCode': 'IN', 'postalCode': '560008', 'cityName': 'BANGALORE', 'lines': ['NO 796 1ST CROSS 12TH MAIN', 'HAL 2ND STAGE INDIRANAGAR']}, 'lastUpdate': '2025-06-03T10:18:45'}, {'chainCode': 'RT', 'iataCode': 'BLR', 'dupeId': 502389611, 'name': 'RT TEST 28JUL25 CLOUD DXM ', 'hotelId': 'RTBLR086', 'geoCode': {'latitude': 0.0, 'longitude': 0.0}, 'address': {'countryCode': 'IN', 'stateCode': 'KA', 'cityName': 'BENGALURU', 'lines': ['MARATHAHALLI']}, 'masterChainCode': 'RT', 'lastUpdate': '2025-07-28T11:34:34'}, {'chainCode': 'ON', 'iataCode': 'BLR', 'dupeId': 700095085, 'name': 'MANIPAL COUNTY', 'hotelId': 'ONBLRMAN', 'geoCode': {'latitude': 12.87298, 'longitude': 77.642}, 'address': {'countryCode': 'IN', 'postalCode': '560068', 'cityName': 'BANGALORE', 'lines': ['65 SINGASANDRA', 'OFF HOSUR ROAD']}, 'lastUpdate': '2025-06-03T10:21:53'}, {'chainCode': 'HN', 'iataCode': 'BLR', 'dupeId': 502389454, 'name': 'TEST PROPERTY HOC LITE UI HOS CLOUD MIGR', 'hotelId': 'HNBLRETA', 'geoCode': {'latitude': 21.9, 'longitude': 28.6}, 'address': {'countryCode': 'IN', 'postalCode': '589000', 'stateCode': 'KA', 'cityName': 'Bengaluru', 'lines': ['TEST ADDRESS']}, 'lastUpdate': '2025-10-07T09:03:23'}, {'chainCode': 'HN', 'iataCode': 'BLR', 'dupeId': 502374522, 'name': 'TEST PROPERTY IN UAT AZURE', 'hotelId': 'HNBLRAZE', 'geoCode': {'latitude': 24.89, 'longitude': 88.9}, 'address': {'countryCode': 'IN', 'postalCode': '560085', 'stateCode': 'KA', 'cityName': 'Bengaluru', 'lines': ['TEST']}, 'lastUpdate': '2025-08-12T10:16:25'}, {'chainCode': 'HS', 'iataCode': 'BLR', 'dupeId': 502195746, 'name': 'TEST PROPERTY FOR DXM', 'hotelId': 'HSBLR901', 'geoCode': {'latitude': 12.96685, 'longitude': 77.58741}, 'address': {'countryCode': 'IN', 'stateCode': 'KA', 'cityName': 'BENGALURU', 'lines': ['LEFISTON STREET']}, 'lastUpdate': '2025-06-03T10:17:52'}, {'chainCode': 'WV', 'iataCode': 'BLR', 'dupeId': 700153996, 'name': 'STERLINGS MAC HOTEL', 'hotelId': 'WVBLRMAT', 'geoCode': {'latitude': 12.9595, 'longitude': 77.65253}, 'address': {'countryCode': 'IN', 'postalCode': '560017', 'cityName': 'BANGALORE', 'lines': ['134 HAL AIRPORT ROAD', 'KODIHALLI']}, 'masterChainCode': 'TC', 'lastUpdate': '2025-06-03T10:18:08'}, {'chainCode': 'HN', 'iataCode': 'BLR', 'dupeId': 502372454, 'name': 'TEST HOTEL', 'hotelId': 'HNBLR9TH', 'geoCode': {'latitude': 12.92139, 'longitude': 77. ...
#
# [{'type': 'flight-offer', 'id': '1', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H45M', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-28T21:35:00'}, 'arrival': {'iataCode': 'BOM', 'terminal': '2', 'at': '2025-10-28T23:20:00'}, 'carrierCode': 'AI', 'number': '2840', 'aircraft': {'code': '32N'}, 'operating': {'carrierCode': 'AI'}, 'duration': 'PT1H45M', 'id': '7', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '74.26'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'}, 'fareDetailsBySegment': [{'segmentId': '7', 'cabin': 'ECONOMY', 'fareBasis': 'WU1YXSII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'W', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'UPGRADE', 'isChargeable': True, 'amenityType': 'UPGRADES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'FREE CHECKED BAGGAGE ALLOWANCE', 'isChargeable': False, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}]}]}]}, {'type': 'flight-offer', 'id': '2', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H50M', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-28T19:20:00'}, 'arrival': {'iataCode': 'BOM', 'terminal': '2', 'at': '2025-10-28T21:10:00'}, 'carrierCode': 'AI', 'number': '610', 'aircraft': {'code': '32N'}, 'operating': {'carrierCode': 'AI'}, 'duration': 'PT1H50M', 'id': '9', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '74.26'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'}, 'fareDetailsBySegment': [{'segmentId': '9', 'cabin': 'ECONOMY', 'fareBasis': 'WU1YXSII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'W', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvid ...
#
# [{'type': 'flight-offer', 'id': '1', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-25T11:00:00'}, 'arrival': {'iataCode': 'COK', 'terminal': '3', 'at': '2025-10-25T12:00:00'}, 'carrierCode': 'AI', 'number': '9451', 'aircraft': {'code': '320'}, 'operating': {'carrierCode': 'IX'}, 'duration': 'PT1H', 'id': '1', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '33.49', 'base': '22.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '33.49'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '33.49', 'base': '22.00'}, 'fareDetailsBySegment': [{'segmentId': '1', 'cabin': 'ECONOMY', 'fareBasis': 'SL1YXYII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'S', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'UPGRADE', 'isChargeable': True, 'amenityType': 'UPGRADES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'FREE CHECKED BAGGAGE ALLOWANCE', 'isChargeable': False, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}]}]}]}, {'type': 'flight-offer', 'id': '2', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '1', 'at': '2025-10-25T15:50:00'}, 'arrival': {'iataCode': 'COK', 'terminal': '3', 'at': '2025-10-25T16:50:00'}, 'carrierCode': 'AI', 'number': '9455', 'aircraft': {'code': '320'}, 'operating': {'carrierCode': 'IX'}, 'duration': 'PT1H', 'id': '2', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '33.49', 'base': '22.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '33.49'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '33.49', 'base': '22.00'}, 'fareDetailsBySegment': [{'segmentId': '2', 'cabin': 'ECONOMY', 'fareBasis': 'SL1YXYII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'S', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', ' ...
#
# [{'chainCode': 'YX', 'iataCode': 'BLR', 'dupeId': 700172728, 'name': 'DAVANAM SAROVAR PORTICO SUITES', 'hotelId': 'YXBLRDSP', 'geoCode': {'latitude': 12.92651, 'longitude': 77.61687}, 'address': {'countryCode': 'IN', 'postalCode': '560068', 'cityName': 'BENGALURU', 'lines': ['DAVANAM PLAZA', 'OPP MADIWALA POLICE STATION, HOSUR MAIN ROAD']}, 'distance': {'value': 1.5, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:18:45'}, {'chainCode': 'OI', 'iataCode': 'BLR', 'dupeId': 700095230, 'name': 'HALCYON BANGALORE', 'hotelId': 'OIBLR049', 'geoCode': {'latitude': 12.93179, 'longitude': 77.62211}, 'address': {'countryCode': 'IN', 'postalCode': '560047', 'cityName': 'Bengaluru', 'lines': ['9 DRAFADILA LAYOUT', '4TH BLOCK KORAMANGALA']}, 'distance': {'value': 1.85, 'unit': 'KM'}, 'masterChainCode': 'LK', 'lastUpdate': '2025-06-03T10:20:11'}, {'chainCode': 'VP', 'iataCode': 'BLR', 'dupeId': 502345474, 'name': 'TEST PROPERTY FOR RESALYS FOR CERTIFICAT', 'hotelId': 'VPBLRAH8', 'geoCode': {'latitude': 12.91458, 'longitude': 77.59954}, 'address': {'countryCode': 'IN', 'postalCode': '560078', 'stateCode': 'KA', 'cityName': 'Bengaluru', 'lines': ['BANGALORE ONE']}, 'distance': {'value': 2.22, 'unit': 'KM'}, 'lastUpdate': '2025-10-08T09:00:11'}, {'chainCode': 'RT', 'iataCode': 'BLR', 'dupeId': 700117806, 'name': 'GRAND MERCURE BANGALORE', 'hotelId': 'RTBLRMER', 'geoCode': {'latitude': 12.92897, 'longitude': 77.62726}, 'address': {'countryCode': 'IN', 'postalCode': '560034', 'cityName': 'BANGALORE', 'lines': ['12TH MAIN - 3RD BLOCK', 'KORAMANGALA']}, 'distance': {'value': 2.45, 'unit': 'KM'}, 'masterChainCode': 'RT', 'lastUpdate': '2025-06-03T10:17:19'}, {'chainCode': 'BW', 'iataCode': 'BLR', 'dupeId': 700144549, 'name': 'BW PREMIER LA MARVELLA', 'hotelId': 'BWBLR552', 'geoCode': {'latitude': 12.93756, 'longitude': 77.58279}, 'address': {'countryCode': 'IN', 'postalCode': '560011', 'cityName': 'BENGALURU', 'lines': ['1 14TH CROSS  SOUTH END CIRCLE']}, 'distance': {'value': 2.46, 'unit': 'KM'}, 'masterChainCode': 'EW', 'lastUpdate': '2025-06-03T10:16:09'}, {'chainCode': 'UZ', 'iataCode': 'BLR', 'dupeId': 700095271, 'name': 'SHILTON ROYALE', 'hotelId': 'UZBLR039', 'geoCode': {'latitude': 12.93859, 'longitude': 77.62981}, 'address': {'countryCode': 'IN', 'postalCode': '560047', 'cityName': 'BANGALORE', 'lines': ['9,100FT ROAD,KORAMANGALA']}, 'distance': {'value': 2.72, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:18:05'}, {'chainCode': 'UZ', 'iataCode': 'BLR', 'dupeId': 700172688, 'name': 'STERLING SUITES LANGFORD TOWN', 'hotelId': 'UZBLR760', 'geoCode': {'latitude': 12.9588, 'longitude': 77.60384}, 'address': {'countryCode': 'IN', 'postalCode': '560025', 'cityName': 'BANGALORE', 'lines': ['21 MOYENVILLE ROAD', 'LANGFORD TOWN KARNATAKA']}, 'distance': {'value': 2.78, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:18:06'}, {'chainCode': 'HS', 'iataCode': 'BLR', 'dupeId': 700151098, 'name': 'ISIS SUITES', 'hotelId': 'HSBLRADW', 'geoCode': {'latitude': 12.93859, 'longitude': 77.6305}, 'address': {'countryCode': 'IN', 'postalCode': '560047', 'cityName': 'BANGALORE', 'lines': ['24, INTERMEDIATE RING ROAD']}, 'distance': {'value': 2.8, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:17:52'}, {'chainCode': 'IL', 'iataCode': 'BLR', 'dupeId': 700212764, 'name': 'CHALET LAKE CITY', 'hotelId': 'ILBLR373', 'geoCode': {'latitude': 12.94099, 'longitude': 77.63077}, 'address': {'countryCode': 'IN', 'postalCode': '560102', 'cityName': 'BANGALORE', 'lines': ['714 6TH BLOCK CELEBRATION']}, 'distance': {'value': 2.89, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:20:33'}, {'chainCode': 'ON', 'iataCode': 'BLR', 'dupeId': 700127596, 'name': 'THE GRAND MAGRATH', 'hotelId': 'ONBLRTGM', 'geoCode': {'latitude': 12.90523, 'longitude': 77.60386}, 'address': {'countryCode': 'IN', 'postalCode': '560025', 'cityName': 'BANGALORE', 'lines': ['30 MAGRATH ROAD']}, 'distance': {'value': 3.17, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:21:53'}]
#
# [{'chainCode': 'YX', 'iataCode': 'BLR', 'dupeId': 700172728, 'name': 'DAVANAM SAROVAR PORTICO SUITES', 'hotelId': 'YXBLRDSP', 'geoCode': {'latitude': 12.92651, 'longitude': 77.61687}, 'address': {'countryCode': 'IN', 'postalCode': '560068', 'cityName': 'BENGALURU', 'lines': ['DAVANAM PLAZA', 'OPP MADIWALA POLICE STATION, HOSUR MAIN ROAD']}, 'distance': {'value': 1.5, 'unit': 'KM'}, 'lastUpdate': '2025-06-03T10:18:45'}, {'chainCode': 'OI', 'iataCode': 'BLR', 'dupeId': 700095230, 'name': 'HALCYON BANGALORE', 'hotelId': 'OIBLR049', 'geoCode': {'latitude': 12.93179, 'longitude': 77.62211}, 'address': {'countryCode': 'IN', 'postalCode': '560047', 'cityName': 'Bengaluru', 'lines': ['9 DRAFADILA LAYOUT', '4TH BLOCK KORAMANGALA']}, 'distance': {'value': 1.85, 'unit': 'KM'}, 'masterChainCode': 'LK', 'lastUpdate': '2025-06-03T10:20:11'}]

# %% [markdown]
# ## Testing the tools

# %%
import tools
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
location_coordinates = tools._get_geocoordinates("Film City, Hyderabad")
print(location_coordinates)
# Out:
# (17.2524153, 78.6798949)

# %%
date_result = tools.get_current_date.invoke({})
date_result
# Out:
# 📅 Getting the current date...
# '2025-10-21'

# %%
search_flight_result = tools.search_flights.invoke({
    "origin": "BLR",
    "destination": "BOM",
    "departure_date": "2025-10-28"
})
search_flight_result
# Out:
# ✈️ Searching for flights from BLR to BOM on 2025-10-28...
#     Adults: 1, Children: 0, Non-stop: True, Max Results: 10
# ✈️  Searching for flights: BLR -> BOM on 2025-10-28
#     Found 10 flights.
#  flight details: [{'type': 'flight-offer', 'id': '1', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H45M', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-28T21:35:00'}, 'arrival': {'iataCode': 'BOM', 'terminal': '2', 'at': '2025-10-28T23:20:00'}, 'carrierCode': 'AI', 'number': '2840', 'aircraft': {'code': '32N'}, 'operating': {'carrierCode': 'AI'}, 'duration': 'PT1H45M', 'id': '7', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '74.26'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'}, 'fareDetailsBySegment': [{'segmentId': '7', 'cabin': 'ECONOMY', 'fareBasis': 'WU1YXSII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'W', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'UPGRADE', 'isChargeable': True, 'amenityType': 'UPGRADES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'FREE CHECKED BAGGAGE ALLOWANCE', 'isChargeable': False, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}]}]}]}, {'type': 'flight-offer', 'id': '2', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H50M', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-28T19:20:00'}, 'arrival': {'iataCode': 'BOM', 'terminal': '2', 'at': '2025-10-28T21:10:00'}, 'carrierCode': 'AI', 'number': '610', 'aircraft': {'code': '32N'}, 'operating': {'carrierCode': 'AI'}, 'duration': 'PT1H50M', 'id': '9', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '74.26'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': True}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'}, 'fareDetailsBySegment': [{'segmentId': '9', 'cabin': 'ECONOMY', 'fareBasis': 'WU1YXSII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'W', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES ...
# [{'type': 'flight-offer',
#   'id': '1',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H45M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T21:35:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T23:20:00'},
#       'carrierCode': 'AI',
#       'number': '2840',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H45M',
#       'id': '7',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '7',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '2',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H50M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T19:20:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T21:10:00'},
#       'carrierCode': 'AI',
#       'number': '610',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H50M',
#       'id': '9',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '9',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '3',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H55M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T09:30:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T11:25:00'},
#       'carrierCode': 'AI',
#       'number': '2852',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H55M',
#       'id': '10',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '10',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '4',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT2H',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T09:20:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T11:20:00'},
#       'carrierCode': 'AI',
#       'number': '604',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT2H',
#       'id': '1',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '5',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT2H10M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T21:25:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T23:35:00'},
#       'carrierCode': 'AI',
#       'number': '642',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT2H10M',
#       'id': '4',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '4',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '6',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 1,
#   'itineraries': [{'duration': 'PT2H5M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T13:50:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T15:55:00'},
#       'carrierCode': 'AI',
#       'number': '2630',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT2H5M',
#       'id': '2',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '74.26',
#    'base': '60.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '74.26'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '74.26', 'base': '60.00'},
#     'fareDetailsBySegment': [{'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '7',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H45M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T06:40:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T08:25:00'},
#       'carrierCode': 'AI',
#       'number': '2402',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H45M',
#       'id': '5',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '75.31',
#    'base': '61.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '75.31'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '75.31', 'base': '61.00'},
#     'fareDetailsBySegment': [{'segmentId': '5',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '8',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H45M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T08:25:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T10:10:00'},
#       'carrierCode': 'AI',
#       'number': '2846',
#       'aircraft': {'code': '321'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H45M',
#       'id': '6',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '75.31',
#    'base': '61.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '75.31'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '75.31', 'base': '61.00'},
#     'fareDetailsBySegment': [{'segmentId': '6',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '9',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT1H50M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T18:30:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T20:20:00'},
#       'carrierCode': 'AI',
#       'number': '2854',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT1H50M',
#       'id': '8',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '75.31',
#    'base': '61.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '75.31'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '75.31', 'base': '61.00'},
#     'fareDetailsBySegment': [{'segmentId': '8',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '10',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'isUpsellOffer': False,
#   'lastTicketingDate': '2025-10-21',
#   'lastTicketingDateTime': '2025-10-21',
#   'numberOfBookableSeats': 9,
#   'itineraries': [{'duration': 'PT2H5M',
#     'segments': [{'departure': {'iataCode': 'BLR',
#        'terminal': '2',
#        'at': '2025-10-28T19:45:00'},
#       'arrival': {'iataCode': 'BOM',
#        'terminal': '2',
#        'at': '2025-10-28T21:50:00'},
#       'carrierCode': 'AI',
#       'number': '2864',
#       'aircraft': {'code': '32N'},
#       'operating': {'carrierCode': 'AI'},
#       'duration': 'PT2H5M',
#       'id': '3',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'EUR',
#    'total': '76.36',
#    'base': '62.00',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '76.36'},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': True},
#   'validatingAirlineCodes': ['AI'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'EUR', 'total': '76.36', 'base': '62.00'},
#     'fareDetailsBySegment': [{'segmentId': '3',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'WU1YXSII',
#       'brandedFare': 'ECOVALU',
#       'brandedFareLabel': 'ECO VALUE',
#       'class': 'W',
#       'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'},
#       'includedCabinBags': {'weight': 7, 'weightUnit': 'KG'},
#       'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT',
#         'isChargeable': False,
#         'amenityType': 'PRE_RESERVED_SEAT',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'MEAL SERVICES',
#         'isChargeable': False,
#         'amenityType': 'MEAL',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'REFUNDABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGEABLE TICKET',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'UPGRADE',
#         'isChargeable': True,
#         'amenityType': 'UPGRADES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'FREE CHECKED BAGGAGE ALLOWANCE',
#         'isChargeable': False,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]}]

# %%
search_hotels_by_city_result = tools.search_hotels_by_city.invoke({
    "city_code": "BLR"
})
search_hotels_by_city_result
# Out:
# 🏨 Searching for hotels in city: BLR...
# 🏨 Searching for hotels in city: BLR
# [{'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700095085,
#   'name': 'MANIPAL COUNTY',
#   'hotelId': 'ONBLRMAN',
#   'geoCode': {'latitude': 12.87298, 'longitude': 77.642},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560068',
#    'cityName': 'BANGALORE',
#    'lines': ['65 SINGASANDRA', 'OFF HOSUR ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346604,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLRV9A',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'QI',
#   'iataCode': 'BLR',
#   'dupeId': 700172727,
#   'name': 'QUALITY INN SHRAVANTHI',
#   'hotelId': 'QIBLR128',
#   'geoCode': {'latitude': 12.89956, 'longitude': 77.57492},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560078',
#    'cityName': 'BENGALURU',
#    'lines': ['60 13TH CROSS, 2ND MAIN', 'J P NAGAR PHASE III']},
#   'masterChainCode': 'EC',
#   'lastUpdate': '2025-06-03T10:17:00'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346486,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLR1P0',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700153996,
#   'name': 'STERLINGS MAC HOTEL',
#   'hotelId': 'WVBLRMAT',
#   'geoCode': {'latitude': 12.9595, 'longitude': 77.65253},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560017',
#    'cityName': 'BANGALORE',
#    'lines': ['134 HAL AIRPORT ROAD', 'KODIHALLI']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700172728,
#   'name': 'DAVANAM SAROVAR PORTICO SUITES',
#   'hotelId': 'YXBLRDSP',
#   'geoCode': {'latitude': 12.92651, 'longitude': 77.61687},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560068',
#    'cityName': 'BENGALURU',
#    'lines': ['DAVANAM PLAZA', 'OPP MADIWALA POLICE STATION, HOSUR MAIN ROAD']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700095099,
#   'name': 'PARK FIELD',
#   'hotelId': 'ILBLR023',
#   'geoCode': {'latitude': 13.1311, 'longitude': 77.85979},
#   'address': {'countryCode': 'IN',
#    'postalCode': '562114',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 154 DODDANALLURA OFF CHINTA']},
#   'lastUpdate': '2025-06-03T10:16:40'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502374880,
#   'name': 'TEST PROPERTY READY FOR PRD AZURE',
#   'hotelId': 'HNBLRDRP',
#   'geoCode': {'latitude': 18.89999, 'longitude': 28.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['996 OLD AIRPORT ROAD LINE ONE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700192655,
#   'name': 'STERLING HOLIDAYS MADHURA',
#   'hotelId': 'ILBLR239',
#   'geoCode': {'latitude': 12.59601, 'longitude': 78.63063},
#   'address': {'countryCode': 'IN',
#    'postalCode': '635853',
#    'cityName': 'YELAGIRI',
#    'lines': ['NO164 ATHANAVUR MAIN ROAD YELA',
#     'TIRUPATTUR TALUK VELLORE DISTRIDT']},
#   'lastUpdate': '2025-06-03T10:20:18'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346100,
#   'name': 'TEST PROP BLR',
#   'hotelId': 'HNBLRFFT',
#   'geoCode': {'latitude': 12.92912, 'longitude': 77.67873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560103',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['PRESTIGE TECH PARK']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'AA',
#   'iataCode': 'BLR',
#   'dupeId': 501381260,
#   'name': 'HOTEL RAMANASHREE BRUNTON',
#   'hotelId': 'AABLRHRB',
#   'geoCode': {'latitude': 12.97228, 'longitude': 77.61508},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'Bengaluru',
#    'lines': ['2/1, BRUNTON ROAD, OFF MG ROAD, OPP OLD PASSPORT OFFICE']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-09T09:03:48'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502346933,
#   'name': 'TEST HOTEL FOR SYNXIS',
#   'hotelId': 'VPBLR62W',
#   'geoCode': {'latitude': 12.99754, 'longitude': 77.55022},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:48'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700083153,
#   'name': 'THE CHEVRON HOTEL',
#   'hotelId': 'ONBLRCHE',
#   'geoCode': {'latitude': 12.98097, 'longitude': 77.60211},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['147 INFANTRY ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502196191,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'RTBLR671',
#   'geoCode': {'latitude': 12.92677, 'longitude': 80.15233},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:18'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346485,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLRYCW',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:40'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700176163,
#   'name': 'WOOD LANDS HOTEL PVT LTD',
#   'hotelId': 'ONBLRWLH',
#   'geoCode': {'latitude': 12.96544, 'longitude': 77.59499},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'cityName': 'BANGALORE',
#    'lines': ['5 RAJA RAM MOHAN ROY ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700120461,
#   'name': 'PALM MEADOWS CLUB',
#   'hotelId': 'YXBLRMEA',
#   'geoCode': {'latitude': 12.97765, 'longitude': 77.74307},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BANGALORE',
#    'lines': ['1 AIRPORT VARTHUR ROAD - WHITEFIELD']},
#   'lastUpdate': '2025-06-03T10:18:46'},
#  {'chainCode': 'SI',
#   'iataCode': 'BLR',
#   'dupeId': 700172690,
#   'name': 'SHERATON BANGALORE',
#   'hotelId': 'SIBLR110',
#   'geoCode': {'latitude': 13.01241, 'longitude': 77.55506},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560055',
#    'cityName': 'BENGALURU',
#    'lines': ['26 1 DR RAJKUMAR ROAD', 'MALLESWARAM RAJAJINAGAR']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-06-03T10:17:33'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502372418,
#   'name': 'TEST PROP FOR DXM 22AUG24',
#   'hotelId': 'RTBLR555',
#   'geoCode': {'latitude': 12.92876, 'longitude': 77.6765},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'LJ',
#   'iataCode': 'BLR',
#   'dupeId': 700047586,
#   'name': 'THE LALIT ASHOK BANGALORE',
#   'hotelId': 'LJBLRI15',
#   'geoCode': {'latitude': 12.99203, 'longitude': 77.58165},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['KUMARA KRUPA HIGH GROUNDS']},
#   'lastUpdate': '2025-06-03T10:20:24'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502195744,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'RTBLR904',
#   'geoCode': {'latitude': 12.92677, 'longitude': 80.15233},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:19'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700212764,
#   'name': 'CHALET LAKE CITY',
#   'hotelId': 'ILBLR373',
#   'geoCode': {'latitude': 12.94099, 'longitude': 77.63077},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560102',
#    'cityName': 'BANGALORE',
#    'lines': ['714 6TH BLOCK CELEBRATION']},
#   'lastUpdate': '2025-06-03T10:20:33'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700145463,
#   'name': 'JUSTA THE RESIDENCE MG ROAD',
#   'hotelId': 'YXBLRJRM',
#   'geoCode': {'latitude': 12.9723, 'longitude': 77.61569},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['NO  21 14  CRAIG PARK LAYOUT M G ROAD']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700095156,
#   'name': 'MAIA BEACON RESIDENCES',
#   'hotelId': 'YXBLRTWW',
#   'geoCode': {'latitude': 12.97951, 'longitude': 77.64624},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560039',
#    'cityName': 'BENGALURU',
#    'lines': ['872/A HAL 2ND STAGE',
#     '80 FEET ROAD INDRANAGAR ,NEAR MICALPALYA']},
#   'lastUpdate': '2025-06-03T10:18:46'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502389912,
#   'name': 'TEST CLOUD DXM 24 AUG ',
#   'hotelId': 'RTBLR921',
#   'geoCode': {'latitude': 0.0, 'longitude': 0.0},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['MARATHAHALLI']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-09-04T17:35:23'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502372459,
#   'name': 'TEST HOTEL 4 FOR SYNXIS',
#   'hotelId': 'VPBLR19Y',
#   'geoCode': {'latitude': 13.00303, 'longitude': 77.54933},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:13'},
#  {'chainCode': 'HL',
#   'iataCode': 'BLR',
#   'dupeId': 700191299,
#   'name': 'HILTON BANGALORE EMBASSY GOLF',
#   'hotelId': 'HLBLR071',
#   'geoCode': {'latitude': 12.94822, 'longitude': 77.64588},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560071',
#    'cityName': 'BANGALORE',
#    'lines': ['SURVEY NO. 5/1 AT CHALAGATTA VILLAGE VARUTHUR HOBLI']},
#   'masterChainCode': 'EH',
#   'lastUpdate': '2025-06-03T10:21:28'},
#  {'chainCode': 'IM',
#   'iataCode': 'BLR',
#   'dupeId': 700054739,
#   'name': 'THE ATRIA',
#   'hotelId': 'IMBLRTAH',
#   'geoCode': {'latitude': 12.96554, 'longitude': 77.58431},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['NO STREET ADDRESS', 'PB NO 5089  NO 1']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-06-03T10:19:30'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502345551,
#   'name': 'TEST NAME WITH AMPERSAND AND APOSTROPHES',
#   'hotelId': 'HNBLRCON',
#   'geoCode': {'latitude': 65.039, 'longitude': 23.2345},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['DCP LINE ONE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502372871,
#   'name': 'TEST HOTEL FOR OMNIBEES',
#   'hotelId': 'VPBLR7O6',
#   'geoCode': {'latitude': 13.00303, 'longitude': 77.54933},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:12'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700054748,
#   'name': 'MONARCH LUXUR',
#   'hotelId': 'ONBLRMON',
#   'geoCode': {'latitude': 12.98016, 'longitude': 77.60493},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['67 INFANTRY ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700117829,
#   'name': 'MGM MARK WHITEFIELD',
#   'hotelId': 'YXBLRMBB',
#   'geoCode': {'latitude': 12.98515, 'longitude': 77.74057},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BANGALORE',
#    'lines': ['23  EPIP ZONE  WHITEFIELD', 'OFF WHITEFIELD MAIN ROAD']},
#   'lastUpdate': '2025-06-03T10:18:46'},
#  {'chainCode': 'TJ',
#   'iataCode': 'BLR',
#   'dupeId': 700024649,
#   'name': 'VIVANTA BY TAJ M G ROAD',
#   'hotelId': 'TJBLRTAJ',
#   'geoCode': {'latitude': 12.97333, 'longitude': 77.61987},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BENGALURU',
#    'lines': ['41 3 MAHATMA GANDHI ROAD']},
#   'lastUpdate': '2025-06-03T10:17:49'},
#  {'chainCode': 'SB',
#   'iataCode': 'BLR',
#   'dupeId': 700218144,
#   'name': 'TEST PROP FOR BK AUTOMATION SB871',
#   'hotelId': 'SBBLR871',
#   'geoCode': {'latitude': 12.97675, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['MARATHALLI SB875']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:21:40'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 700095230,
#   'name': 'HALCYON BANGALORE',
#   'hotelId': 'OIBLR049',
#   'geoCode': {'latitude': 12.93179, 'longitude': 77.62211},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560047',
#    'cityName': 'Bengaluru',
#    'lines': ['9 DRAFADILA LAYOUT', '4TH BLOCK KORAMANGALA']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:20:11'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502372872,
#   'name': 'TEST PROPERTY FOR CONTENT API',
#   'hotelId': 'HNBLRRRE',
#   'geoCode': {'latitude': 20.2, 'longitude': 40.4},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560077',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['MYSORE VIJAYANAGAR']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'UI',
#   'iataCode': 'BLR',
#   'dupeId': 700141182,
#   'name': 'FORTUNE PARK JP CELESTIAL',
#   'hotelId': 'UIBLRJPC',
#   'geoCode': {'latitude': 12.98088, 'longitude': 77.57594},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560009',
#    'cityName': 'BANGALORE',
#    'lines': ['RACE COURSE ROAD', '5/43 SESHADRI ROAD']},
#   'lastUpdate': '2025-06-03T10:18:01'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502373383,
#   'name': 'TEST HOTEL FOR RESERVIT 2',
#   'hotelId': 'VPBLR238',
#   'geoCode': {'latitude': 12.99771, 'longitude': 77.55029},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:12'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346484,
#   'name': 'GINGER',
#   'hotelId': 'OIBLRRQ4',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346687,
#   'name': 'GINGER',
#   'hotelId': 'OIBLR9ZW',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502389676,
#   'name': 'RT TEST TEST CLOUD DXM 31 JUL ',
#   'hotelId': 'RTBLR115',
#   'geoCode': {'latitude': 0.0, 'longitude': 0.0},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['MARATHAHALLI']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-07-31T10:01:34'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502345999,
#   'name': 'TEST HOTEL FOR RESERVIT',
#   'hotelId': 'VPBLRGR3',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:48'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502195746,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR901',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346678,
#   'name': 'TEST FOR BNA',
#   'hotelId': 'HNBLR055',
#   'geoCode': {'latitude': 12.0, 'longitude': 14.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560089',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['996 OLD AIRPORT ROAD LINE ONE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502346069,
#   'name': 'TEST HOTEL FOR PRIMALRES CERTIFICATION',
#   'hotelId': 'VPBLRAHF',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346768,
#   'name': 'RAMADA',
#   'hotelId': 'OIBLR59C',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:49'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502372870,
#   'name': 'TEST PROP FOR DOCS',
#   'hotelId': 'VPBLR0RB',
#   'geoCode': {'latitude': 13.00639, 'longitude': 77.59316},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560006',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['JC NAGAR']},
#   'lastUpdate': '2025-10-07T09:03:12'},
#  {'chainCode': 'TA',
#   'iataCode': 'BLR',
#   'dupeId': 700054754,
#   'name': 'ST. MARKS HOTEL',
#   'hotelId': 'TABLR017',
#   'geoCode': {'latitude': 12.96906, 'longitude': 77.60034},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['4   1   ST MARKS  ROAD', 'NEAR RESIDENCY ROAD']},
#   'lastUpdate': '2025-06-03T10:17:45'},
#  {'chainCode': 'SX',
#   'iataCode': 'BLR',
#   'dupeId': 700153995,
#   'name': 'LEMON TREE PREMIER ULSOOR LAKE BENGALURU',
#   'hotelId': 'SXBLRLTH',
#   'geoCode': {'latitude': 12.98655, 'longitude': 77.61584},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560042',
#    'cityName': 'BENGALURU',
#    'lines': ['ST JOHNS ROAD', 'ULSOOR LAKE']},
#   'lastUpdate': '2025-06-03T10:17:36'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502372451,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLR006',
#   'geoCode': {'latitude': 89.69, 'longitude': 56.36},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:13:02'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502195749,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR904',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346470,
#   'name': 'TEST4',
#   'hotelId': 'OIBLR3PG',
#   'geoCode': {'latitude': 12.95677, 'longitude': 77.70119},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['MARATHALLI']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502389458,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLRUAT',
#   'geoCode': {'latitude': 12.81318, 'longitude': 77.57872},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:22:31'},
#  {'chainCode': 'DH',
#   'iataCode': 'BLR',
#   'dupeId': 700211593,
#   'name': 'THE RITZ CARLTON, BANGALORE',
#   'hotelId': 'DHBLRAHU',
#   'geoCode': {'latitude': 12.96707, 'longitude': 77.5992},
#   'address': {'countryCode': 'IN',
#    'cityName': 'BANGALORE',
#    'lines': ['NUMBER 99, RESIDENCY ROAD BANGALORE, KARNATAKA', '560025,']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:21:31'},
#  {'chainCode': 'RZ',
#   'iataCode': 'BLR',
#   'dupeId': 700211593,
#   'name': 'THE RITZ-CARLTON BANGALORE',
#   'hotelId': 'RZBLRRZZ',
#   'geoCode': {'latitude': 12.96914, 'longitude': 77.60165},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'cityName': 'BANGALORE',
#    'lines': ['NUMBER 99 RESIDENCY ROAD']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-06-03T10:17:30'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502374915,
#   'name': 'TEST PROPERTY FOR MIGARTION AZURE',
#   'hotelId': 'HNBLRPOS',
#   'geoCode': {'latitude': 12.9, 'longitude': 40.79999},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BANGALORE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346593,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLRJIV',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BANGALORE']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'TA',
#   'iataCode': 'BLR',
#   'dupeId': 700155158,
#   'name': 'PREMIER INN BANGALORE WHITEFIELD',
#   'hotelId': 'TABLR488',
#   'geoCode': {'latitude': 12.98155, 'longitude': 77.70878},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BENGALURU',
#    'lines': ['3A1, BROOKFIELD MAIN ROAD', 'OPP.IFB CAMPUS, WHITEFIELD']},
#   'lastUpdate': '2025-06-03T10:17:46'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502375059,
#   'name': 'HN PROP CREATE TEST SECO',
#   'hotelId': 'HNBLRPCS',
#   'geoCode': {'latitude': 13.00461, 'longitude': 77.69586},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560047',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST ROAD BENGALURU']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502196182,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR672',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700071686,
#   'name': 'THE BELL HOTEL',
#   'hotelId': 'ONBLRBEL',
#   'geoCode': {'latitude': 12.97068, 'longitude': 77.58423},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560023',
#    'cityName': 'BANGALORE',
#    'lines': ['DISTRICT OFFICE ROAD 88']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700182818,
#   'name': 'GOLDEN LANDMARK HOTEL',
#   'hotelId': 'ILBLR026',
#   'geoCode': {'latitude': 12.98138, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560009',
#    'cityName': 'BANGALORE',
#    'lines': ['20 21 SESHADRI ROAD']},
#   'lastUpdate': '2025-06-03T10:18:56'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700054749,
#   'name': 'MUSEUM INN HOTEL',
#   'hotelId': 'ILBLR700',
#   'geoCode': {'latitude': 12.97614, 'longitude': 77.60366},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BENGALURU',
#    'lines': ['1 MUSEUM RD OFF M G ROAD']},
#   'lastUpdate': '2025-06-03T10:17:00'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700095273,
#   'name': 'THE PAUL BANGALORE',
#   'hotelId': 'WVBLRPAL',
#   'geoCode': {'latitude': 12.95644, 'longitude': 77.64148},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560071',
#    'cityName': 'BANGALORE',
#    'lines': ['139/28, DOMLUR LAYOUT', 'OFF INTERMEDIATE RING ROAD']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700095249,
#   'name': 'IVY UNWIND ISLAND HOTEL',
#   'hotelId': 'ONBLRIVY',
#   'geoCode': {'latitude': 12.96464, 'longitude': 77.7022},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560087',
#    'cityName': 'BANGALORE',
#    'lines': ['INFANTS NEST MARATHAHALLI RING ROAD', 'KARNATAKA']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700191296,
#   'name': 'CREST EXECUTIVE SUITES',
#   'hotelId': 'WVBLR429',
#   'geoCode': {'latitude': 12.99213, 'longitude': 77.69895},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560048',
#    'cityName': 'BANGALORE',
#    'lines': ['GATE NO 1 PRESTIGE SHANTINIKETAN', 'ITPL ROAD WHITEFIELD']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502389459,
#   'name': 'TEST PROPERTY91 PARALLEL',
#   'hotelId': 'HNBLRUUU',
#   'geoCode': {'latitude': 12.0, 'longitude': 14.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:22:51'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 501444428,
#   'name': 'CITRUS CUNNINGHAM ROAD BANGALORE',
#   'hotelId': 'WVBLR396',
#   'geoCode': {'latitude': 12.98611, 'longitude': 77.59546},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560052',
#    'cityName': 'BENGALURU',
#    'lines': ['34 CUNNINGHAM ROAD VASANTH NAGAR']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-10-07T09:03:16'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700095215,
#   'name': 'JUSTA THE RESIDENCE INDIRANAGA',
#   'hotelId': 'YXBLRJRI',
#   'geoCode': {'latitude': 12.97096, 'longitude': 77.64062},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560008',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 796 1ST CROSS 12TH MAIN', 'HAL 2ND STAGE INDIRANAGAR']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'MC',
#   'iataCode': 'BLR',
#   'dupeId': 700191294,
#   'name': 'BENGALURU MARRIOTT WHITEFIELD',
#   'hotelId': 'MCBLRWFM',
#   'geoCode': {'latitude': 12.98051, 'longitude': 77.72784},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BENGALURU',
#    'lines': ['8TH ROAD PLOT NO 75 EPIP AREA']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-06-03T10:19:13'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 700151098,
#   'name': 'ISIS SUITES',
#   'hotelId': 'HSBLRADW',
#   'geoCode': {'latitude': 12.93859, 'longitude': 77.6305},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560047',
#    'cityName': 'BANGALORE',
#    'lines': ['24, INTERMEDIATE RING ROAD']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346809,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLRJI6',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502346363,
#   'name': 'TEST HOTEL FOR TRAVEL CLICK CERTIFICATIO',
#   'hotelId': 'VPBLR18H',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502389611,
#   'name': 'RT TEST 28JUL25 CLOUD DXM ',
#   'hotelId': 'RTBLR086',
#   'geoCode': {'latitude': 0.0, 'longitude': 0.0},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['MARATHAHALLI']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-07-28T11:34:34'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346834,
#   'name': 'TEST PROPERTY BLR',
#   'hotelId': 'HNBLR457',
#   'geoCode': {'latitude': 45.36, 'longitude': 56.39},
#   'address': {'countryCode': 'IN',
#    'postalCode': '56008',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:14:22'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502372443,
#   'name': 'TEST HOTEL',
#   'hotelId': 'OIBLR90Y',
#   'geoCode': {'latitude': 12.92876, 'longitude': 77.6765},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:22:02'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502374587,
#   'name': 'TEST PROPERTY IN CLOUD GCC',
#   'hotelId': 'HNBLRGCC',
#   'geoCode': {'latitude': 24.2, 'longitude': 29.7},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560072',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST CLOUD']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502347289,
#   'name': 'LK PENTEST PROPERTY',
#   'hotelId': 'OIBLRWRM',
#   'geoCode': {'latitude': 13.01259, 'longitude': 77.66535},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560016',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['SOME HOTEL IN INDIA']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:04'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700172703,
#   'name': 'SAFINA HOTEL',
#   'hotelId': 'ONBLRSAF',
#   'geoCode': {'latitude': 12.98106, 'longitude': 77.60217},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['84/85 INFANTRY ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502347373,
#   'name': 'TEST HOTEL',
#   'hotelId': 'HNBLRPRT',
#   'geoCode': {'latitude': 12.8, 'longitude': 29.8},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:20:11'},
#  {'chainCode': 'HI',
#   'iataCode': 'BLR',
#   'dupeId': 502195751,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HIBLR900',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': '6C',
#   'lastUpdate': '2025-06-03T10:16:02'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502373812,
#   'name': 'TEST PROPERTY FOR HN FEB',
#   'hotelId': 'HNBLR212',
#   'geoCode': {'latitude': 90.1, 'longitude': 89.9},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560006',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['JC NAGAR']},
#   'lastUpdate': '2025-08-12T10:14:12'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502374522,
#   'name': 'TEST PROPERTY IN UAT AZURE',
#   'hotelId': 'HNBLRAZE',
#   'geoCode': {'latitude': 24.89, 'longitude': 88.9},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560085',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:16:25'},
#  {'chainCode': 'UZ',
#   'iataCode': 'BLR',
#   'dupeId': 700212747,
#   'name': 'AURICK HOTEL',
#   'hotelId': 'UZBLRAKH',
#   'geoCode': {'latitude': 12.89794, 'longitude': 77.58813},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560078',
#    'cityName': 'BENGALURU',
#    'lines': ['598 15TH CROSS  35TH MAIN', '6TH PHASE  JP NAGAR KARNATAKA']},
#   'lastUpdate': '2025-06-03T10:18:06'},
#  {'chainCode': 'TJ',
#   'iataCode': 'BLR',
#   'dupeId': 700120479,
#   'name': 'THE GATEWAY HOTEL KM ROAD',
#   'hotelId': 'TJBLRTGR',
#   'geoCode': {'latitude': 13.33653, 'longitude': 75.81744},
#   'address': {'countryCode': 'IN',
#    'postalCode': '577102',
#    'cityName': 'CHIKMAGALUR',
#    'lines': ['K M ROAD, OPP. PAVITRA VANNA', 'JYOTHINAGAR']},
#   'lastUpdate': '2025-06-03T10:17:49'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502345478,
#   'name': 'TEST FOR CONFIG LSS',
#   'hotelId': 'HNBLRSRM',
#   'geoCode': {'latitude': 12.84457, 'longitude': 77.58369},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['ADDRESS ONE']},
#   'lastUpdate': '2025-10-08T09:00:09'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502195741,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'RTBLR901',
#   'geoCode': {'latitude': 12.92677, 'longitude': 80.15233},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:19'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346472,
#   'name': 'ENCORE',
#   'hotelId': 'OIBLRXVZ',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700127596,
#   'name': 'THE GRAND MAGRATH',
#   'hotelId': 'ONBLRTGM',
#   'geoCode': {'latitude': 12.90523, 'longitude': 77.60386},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'cityName': 'BANGALORE',
#    'lines': ['30 MAGRATH ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502373645,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLR123',
#   'geoCode': {'latitude': 13.00576, 'longitude': 77.62492},
#   'address': {'countryCode': 'IN',
#    'postalCode': '123456',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['STREET10 1']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 700117806,
#   'name': 'GRAND MERCURE BANGALORE',
#   'hotelId': 'RTBLRMER',
#   'geoCode': {'latitude': 12.92897, 'longitude': 77.62726},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560034',
#    'cityName': 'BANGALORE',
#    'lines': ['12TH MAIN - 3RD BLOCK', 'KORAMANGALA']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:19'},
#  {'chainCode': 'BD',
#   'iataCode': 'BLR',
#   'dupeId': 502372452,
#   'name': 'TEST PROP',
#   'hotelId': 'BDBLRMAR',
#   'geoCode': {'latitude': 12.95396, 'longitude': 77.70019},
#   'address': {'countryCode': 'IN',
#    'postalCode': '456030',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['MARATHALLI ROAD']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-01T05:57:05'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502372416,
#   'name': 'GINGER',
#   'hotelId': 'OIBLRA6A',
#   'geoCode': {'latitude': 12.92876, 'longitude': 77.6765},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'TJ',
#   'iataCode': 'BLR',
#   'dupeId': 700031650,
#   'name': 'THE GATEWAY HOTEL RESIDENCY RD',
#   'hotelId': 'TJBLRGAT',
#   'geoCode': {'latitude': 12.96872, 'longitude': 77.6014},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'cityName': 'BANGALORE',
#    'lines': ['66 RESIDENCY ROAD,KARNATAKA']},
#   'lastUpdate': '2025-06-03T10:17:49'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700159965,
#   'name': 'TDCMDW18 TESTING',
#   'hotelId': 'WVBLRIOP',
#   'geoCode': {'latitude': 12.97675, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'postalCode': '56478',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['WELCOME TEST', 'WEUID']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:22:03'},
#  {'chainCode': 'TJ',
#   'iataCode': 'BLR',
#   'dupeId': 700142603,
#   'name': 'VIVANTA BY TAJ WHITEFIELD',
#   'hotelId': 'TJBLRITP',
#   'geoCode': {'latitude': 12.98668, 'longitude': 77.73773},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BANGALORE',
#    'lines': ['INTERNATIONAL TECHNOLOGY PARK', 'WHITEFIELD MAIN ROAD']},
#   'lastUpdate': '2025-06-03T10:17:49'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700095136,
#   'name': 'FORTUNE SELECT JP COSMOS',
#   'hotelId': 'WVBLR845',
#   'geoCode': {'latitude': 12.98971, 'longitude': 77.59462},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560052',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 49 CUNNINGHAM CRESCENT ROAD', 'BEHIND SIGMA MALL']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502389384,
#   'name': 'CRETAN TEST PROPERTY',
#   'hotelId': 'VPBLR47S',
#   'geoCode': {'latitude': 12.96629, 'longitude': 77.57733},
#   'address': {'countryCode': 'IN',
#    'postalCode': '123456',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['STREET10 1']},
#   'lastUpdate': '2025-10-07T09:03:12'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502391162,
#   'name': 'TEST HOTEL',
#   'hotelId': 'HNBLRKKL',
#   'geoCode': {'latitude': 0.0, 'longitude': 0.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560012',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-10-20T06:35:40'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502374691,
#   'name': 'TEST PROP',
#   'hotelId': 'VPBLR1A4',
#   'geoCode': {'latitude': 13.0072, 'longitude': 77.62479},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['STREET1']},
#   'lastUpdate': '2025-06-03T10:22:01'},
#  {'chainCode': 'UZ',
#   'iataCode': 'BLR',
#   'dupeId': 700182579,
#   'name': 'OLDE BANGALORE RESORT',
#   'hotelId': 'UZBLR219',
#   'geoCode': {'latitude': 13.19315, 'longitude': 77.62253},
#   'address': {'countryCode': 'IN',
#    'postalCode': '562157',
#    'cityName': 'BANGALORE',
#    'lines': ['206 TARABANAHALLI CHIKKAJALA POST']},
#   'lastUpdate': '2025-06-03T10:18:05'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502372869,
#   'name': 'TEST PROPERTY FOR CONTENT',
#   'hotelId': 'HNBLROOP',
#   'geoCode': {'latitude': 12.49, 'longitude': 48.9},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560072',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['MYSORE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'XL',
#   'iataCode': 'BLR',
#   'dupeId': 700151102,
#   'name': 'THE ZURI WHITEFIELD BENGALURU',
#   'hotelId': 'XLBLRTZH',
#   'geoCode': {'latitude': 12.96554, 'longitude': 77.58431},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560048',
#    'cityName': 'BANGALORE',
#    'lines': ['RAJPALYA HOODI', 'ITPL ROAD WHITEFIELD']},
#   'lastUpdate': '2025-06-03T10:18:41'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346731,
#   'name': 'GINGER',
#   'hotelId': 'OIBLR3IO',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 700082344,
#   'name': 'JAYA MAHAL PALACE',
#   'hotelId': 'HSBLRABL',
#   'geoCode': {'latitude': 13.00312, 'longitude': 77.57899},
#   'address': {'countryCode': 'IN',
#    'cityName': 'BANGALORE',
#    'lines': ['JAYAMAHAL MAIN ROAD 1']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'DH',
#   'iataCode': 'BLR',
#   'dupeId': 700216954,
#   'name': 'JW MARRIOTT HOTEL BENGALURU',
#   'hotelId': 'DHBLRALL',
#   'geoCode': {'latitude': 12.97116, 'longitude': 77.59769},
#   'address': {'countryCode': 'IN',
#    'cityName': 'BANGALORE',
#    'lines': ['24/1 VITTAL MALLYA ROAD - BENGALURU, 560001 INDIA']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:21:31'},
#  {'chainCode': 'MC',
#   'iataCode': 'BLR',
#   'dupeId': 700216954,
#   'name': 'JW MARRIOTT HOTEL BENGALURU',
#   'hotelId': 'MCBLRJWM',
#   'geoCode': {'latitude': 12.96978, 'longitude': 77.59444},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BENGALURU',
#    'lines': ['24 1 VITTAL MALLYA ROAD']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-06-03T10:16:47'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700150828,
#   'name': 'THE CHANCERY PAVILION',
#   'hotelId': 'WVBLR907',
#   'geoCode': {'latitude': 12.96838, 'longitude': 77.60101},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560025',
#    'cityName': 'BANGALORE',
#    'lines': ['135 RESIDENCY ROAD']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'UZ',
#   'iataCode': 'BLR',
#   'dupeId': 700176153,
#   'name': 'HOTEL EMPIRE SUITES- CASTLE STREET',
#   'hotelId': 'UZBLR389',
#   'geoCode': {'latitude': 12.96715, 'longitude': 77.60908},
#   'address': {'countryCode': 'IN',
#    'postalCode': '550025',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 35CASTLE STREET', 'OFF BRIGADEROAD']},
#   'lastUpdate': '2025-06-03T10:18:05'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700212944,
#   'name': 'THE IRIS INN HOTEL',
#   'hotelId': 'ONBLRIRI',
#   'geoCode': {'latitude': 12.99098, 'longitude': 77.68798},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560048',
#    'cityName': 'BANGALORE',
#    'lines': ['21 AND 22 AND 3 OUTER RENG ROAD',
#     'NEAR EMC2 AND MORE MEGA STORE']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700182527,
#   'name': 'HOTEL IVORY TOWER',
#   'hotelId': 'ILBLR021',
#   'geoCode': {'latitude': 12.97533, 'longitude': 77.60942},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['12TH FLOOR BARTON CENTRE 84 MG']},
#   'lastUpdate': '2025-06-03T10:17:34'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346288,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLRBAR',
#   'geoCode': {'latitude': 13.02247, 'longitude': 77.56128},
#   'address': {'countryCode': 'IN',
#    'postalCode': '571108',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:16:32'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502345878,
#   'name': 'TEST HOTEL FOR SITEMINDER',
#   'hotelId': 'VPBLR401',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:04'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502322169,
#   'name': 'TEST PROP VEERA',
#   'hotelId': 'RTBLR110',
#   'geoCode': {'latitude': 12.95448, 'longitude': 77.70032},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:18'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502196184,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR674',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'AL',
#   'iataCode': 'BLR',
#   'dupeId': 700211496,
#   'name': 'ALOFT BENGALURU CESSNA PARK',
#   'hotelId': 'ALBLR545',
#   'geoCode': {'latitude': 12.93439, 'longitude': 77.69448},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560103',
#    'cityName': 'BENGALURU',
#    'lines': ['CESSNA BUSINESS PARK SARJAPUR',
#     'KADUBEESANAHALLI BELLANDUR POS']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-08-04T06:06:07'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700041157,
#   'name': 'NALAPAD RESIDENCY',
#   'hotelId': 'ILBLR027',
#   'geoCode': {'latitude': 12.98138, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560009',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 19 K G  ROAD']},
#   'lastUpdate': '2025-06-03T10:18:56'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502346364,
#   'name': 'TEST HOTEL FOR HNS CERTIFICATION',
#   'hotelId': 'VPBLR3RR',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502372445,
#   'name': 'TEST PROPERTY BK',
#   'hotelId': 'HNBLRLPP',
#   'geoCode': {'latitude': 12.0, 'longitude': 14.8},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560082',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:18:51'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 501825781,
#   'name': 'BANGALORE GATE',
#   'hotelId': 'HSBLRABU',
#   'geoCode': {'latitude': 12.97369, 'longitude': 77.57908},
#   'address': {'countryCode': 'IN',
#    'cityName': 'BANGALORE',
#    'lines': ['9 - 12 GAJANANA TOWERS,K G ROAD']},
#   'lastUpdate': '2025-10-07T09:03:14'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502389292,
#   'name': 'DERBY TEST PROPERTY 2',
#   'hotelId': 'VPBLR22T',
#   'geoCode': {'latitude': 13.00576, 'longitude': 77.62492},
#   'address': {'countryCode': 'IN',
#    'postalCode': '123456',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['STREET10 1']},
#   'lastUpdate': '2025-10-07T09:03:12'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502195747,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR902',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'HI',
#   'iataCode': 'BLR',
#   'dupeId': 502196185,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HIBLR670',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': '6C',
#   'lastUpdate': '2025-06-03T10:16:35'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502372462,
#   'name': 'RIVER TEST',
#   'hotelId': 'OIBLRZHR',
#   'geoCode': {'latitude': 13.01321, 'longitude': 77.59358},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560006',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['RT NAGAR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:04'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 900128746,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'OIBLR777',
#   'geoCode': {'latitude': 12.91617, 'longitude': 77.63826},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560102',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T08:15:31'},
#  {'chainCode': 'XL',
#   'iataCode': 'BLR',
#   'dupeId': 501506518,
#   'name': 'MY FORTUNE BENGALURU SUMMIT',
#   'hotelId': 'XLBLRFHH',
#   'geoCode': {'latitude': 12.96895, 'longitude': 77.61447},
#   'address': {'countryCode': 'IN',
#    'cityName': 'BENGALURU',
#    'lines': ['46 RICHMOND ROAD', 'RICHMOND TOWN']},
#   'lastUpdate': '2025-10-09T09:03:36'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700140790,
#   'name': 'CLARKS EXOTICA RESORT AND SPA',
#   'hotelId': 'YXBLR009',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'postalCode': '562110',
#    'cityName': 'BENGALURU',
#    'lines': ['SWISS TOWN', 'HOLLYWOOD JUNCTION SADAHALLI POST']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346327,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLR569',
#   'geoCode': {'latitude': 13.02247, 'longitude': 77.56128},
#   'address': {'countryCode': 'IN',
#    'postalCode': '58963',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:14:42'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346582,
#   'name': 'GINGER',
#   'hotelId': 'OIBLRKQ4',
#   'geoCode': {'latitude': 12.95677, 'longitude': 77.70119},
# ...
#   'dupeId': 502372457,
#   'name': 'TEST HOTEL 2 FOR SYNXIS',
#   'hotelId': 'VPBLR1I8',
#   'geoCode': {'latitude': 13.00303, 'longitude': 77.54933},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:13'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502373704,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLR857',
#   'geoCode': {'latitude': 78.98, 'longitude': 80.45},
#   'address': {'countryCode': 'IN',
#    'postalCode': '56008',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:15:13'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502389454,
#   'name': 'TEST PROPERTY HOC LITE UI HOS CLOUD MIGR',
#   'hotelId': 'HNBLRETA',
#   'geoCode': {'latitude': 21.9, 'longitude': 28.6},
#   'address': {'countryCode': 'IN',
#    'postalCode': '589000',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST ADDRESS']},
#   'lastUpdate': '2025-10-07T09:03:23'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700191303,
#   'name': 'SPRINGS HOTEL AND SPA BANGALOR',
#   'hotelId': 'YXBLRSPR',
#   'geoCode': {'latitude': 12.96627, 'longitude': 77.58707},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560002',
#    'cityName': 'BANGALORE',
#    'lines': ['19 SIDDAIAH ROAD', 'OFF JC ROAD BEFORE URVASI THEATER']},
#   'lastUpdate': '2025-06-03T10:18:46'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700212937,
#   'name': 'THE CLUB',
#   'hotelId': 'ILBLR342',
#   'geoCode': {'latitude': 12.93903, 'longitude': 77.52288},
#   'address': {'countryCode': 'FR',
#    'postalCode': '560039',
#    'cityName': 'PARIS',
#    'lines': ['MYSORE ROAD', 'MARTHALLIROAD']},
#   'lastUpdate': '2025-06-03T10:20:32'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 502373133,
#   'name': 'SWA TEST UAT PROPE',
#   'hotelId': 'WVBLRIOQ',
#   'geoCode': {'latitude': 12.97675, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['KASARGOD', 'MEEPUGURI']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:22:03'},
#  {'chainCode': 'UZ',
#   'iataCode': 'BLR',
#   'dupeId': 700095271,
#   'name': 'SHILTON ROYALE',
#   'hotelId': 'UZBLR039',
#   'geoCode': {'latitude': 12.93859, 'longitude': 77.62981},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560047',
#    'cityName': 'BANGALORE',
#    'lines': ['9,100FT ROAD,KORAMANGALA']},
#   'lastUpdate': '2025-06-03T10:18:05'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346769,
#   'name': 'HOTEL MSD',
#   'hotelId': 'HNBLRLIA',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700054734,
#   'name': 'HOTEL CHANCERY',
#   'hotelId': 'WVBLRR12',
#   'geoCode': {'latitude': 12.96929, 'longitude': 77.59725},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['LAVELLE ROAD 10/6']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346471,
#   'name': 'GINGER',
#   'hotelId': 'OIBLR6HB',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:21:39'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700140791,
#   'name': 'RADHA REGENT - BANGALORE',
#   'hotelId': 'YXBLR512',
#   'geoCode': {'latitude': 12.84626, 'longitude': 77.67148},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560100',
#    'cityName': 'BENGALURU',
#    'lines': ['110C ELECTRONICS CITY', 'PHASE1 NEAR FIRE STATION']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502195742,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'RTBLR902',
#   'geoCode': {'latitude': 12.92677, 'longitude': 80.15233},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:19'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346606,
#   'name': 'TEST PROPERTY FOR IND',
#   'hotelId': 'HNBLR033',
#   'geoCode': {'latitude': 12.0, 'longitude': 14.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560089',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['996 OLD AIRPORT ROAD LINE ONE']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'RT',
#   'iataCode': 'BLR',
#   'dupeId': 502322423,
#   'name': 'VEE TEST NRT PROPERTTT',
#   'hotelId': 'RTBLR444',
#   'geoCode': {'latitude': 40.41669, 'longitude': -3.70035},
#   'address': {'countryCode': 'ES',
#    'cityName': 'MADRID',
#    'lines': ['LEFISTON STREET']},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:18'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502389457,
#   'name': 'TEST PROPERTY FOR PTO',
#   'hotelId': 'HNBLRPTO',
#   'geoCode': {'latitude': 12.98527, 'longitude': 77.72445},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560082',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST ADDRESS']},
#   'lastUpdate': '2025-10-07T09:03:23'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502177867,
#   'name': 'NEWP',
#   'hotelId': 'OIBLR789',
#   'geoCode': {'latitude': 12.93085, 'longitude': 77.68339},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560103',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['PRESTIGE TECH PARK,KODBISANHALLI,']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:27'},
#  {'chainCode': 'HS',
#   'iataCode': 'BLR',
#   'dupeId': 502196181,
#   'name': 'TEST PROPERTY FOR DXM',
#   'hotelId': 'HSBLR671',
#   'geoCode': {'latitude': 12.96685, 'longitude': 77.58741},
#   'address': {'countryCode': 'IN',
#    'stateCode': 'KA',
#    'cityName': 'BENGALURU',
#    'lines': ['LEFISTON STREET']},
#   'lastUpdate': '2025-06-03T10:17:52'},
#  {'chainCode': 'SX',
#   'iataCode': 'BLR',
#   'dupeId': 700156096,
#   'name': 'LEMON TREE HOTEL WHITEFIELD',
#   'hotelId': 'SXBLRWHI',
#   'geoCode': {'latitude': 12.9724, 'longitude': 77.7178},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BENGALURU',
#    'lines': ['23 EPIP ZONE', 'WHITEFIELD']},
#   'lastUpdate': '2023-06-15T10:35:37'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700212929,
#   'name': 'SUNRAY HOTEL - BANGALORE',
#   'hotelId': 'YXBLRSHB',
#   'geoCode': {'latitude': 12.95191, 'longitude': 77.6998},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560087',
#    'cityName': 'BANGALORE',
#    'lines': ['OPP PRESTIGE TECH PARK', 'MARTHAHALLI OUTER RING ROAD']},
#   'lastUpdate': '2025-06-03T10:18:46'},
#  {'chainCode': 'CI',
#   'iataCode': 'BLR',
#   'dupeId': 700018176,
#   'name': 'COMFORT INN VIJAY RESIDENCY',
#   'hotelId': 'CIBLR027',
#   'geoCode': {'latitude': 13.0235, 'longitude': 77.55784},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560009',
#    'cityName': 'BANGALORE',
#    'lines': ['18, 111 MAIN ROAD']},
#   'masterChainCode': 'EC',
#   'lastUpdate': '2025-06-03T10:19:19'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502374998,
#   'name': 'TEST HOTEL FOR SYNXIS 5',
#   'hotelId': 'VPBLR9XM',
#   'geoCode': {'latitude': 13.0059, 'longitude': 77.54885},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:19'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700076909,
#   'name': 'JUSTA THE RESIDENCE OFF MG ROA',
#   'hotelId': 'YXBLR184',
#   'geoCode': {'latitude': 12.96554, 'longitude': 77.58431},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560042',
#    'cityName': 'BANGALORE',
#    'lines': ['NO 30 1 2ND CROSS', 'ULSOOR ROAD']},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502373216,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLRB27',
#   'geoCode': {'latitude': 28.0, 'longitude': 24.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560098',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:17:51'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346371,
#   'name': 'TEST HOTEL FOR BOOKING EXPERT CERTIFICAT',
#   'hotelId': 'OIBLRBEK',
#   'geoCode': {'latitude': 13.00724, 'longitude': 77.54873},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502372458,
#   'name': 'TEST HOTEL 3 FOR SYNXIS',
#   'hotelId': 'VPBLR01W',
#   'geoCode': {'latitude': 13.00303, 'longitude': 77.54933},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['WEST OF CORD ROAD']},
#   'lastUpdate': '2025-10-07T09:03:13'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700083154,
#   'name': 'SAMRUDHII SUITES',
#   'hotelId': 'ILBLR029',
#   'geoCode': {'latitude': 12.98138, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560100',
#    'cityName': 'BANGALORE',
#    'lines': ['941  951 DODDA THOGUR VILLAGE']},
#   'lastUpdate': '2025-06-03T10:19:07'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346594,
#   'name': 'HOTEL SWAGATH',
#   'hotelId': 'OIBLRWOG',
#   'geoCode': {'latitude': 13.01259, 'longitude': 77.66535},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560016',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['SOME HOTEL IN INDIA']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502374996,
#   'name': 'TEST PROPERTY FOR HOS CLOUD DRY RUN 2',
#   'hotelId': 'HNBLRCLL',
#   'geoCode': {'latitude': 23.9, 'longitude': 45.8},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560083',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST ADDRESS']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'ON',
#   'iataCode': 'BLR',
#   'dupeId': 700095117,
#   'name': 'HOTEL KOMFORT TERRACES',
#   'hotelId': 'ONBLRHKT',
#   'geoCode': {'latitude': 12.97505, 'longitude': 77.60684},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BENGALURU',
#    'lines': ['301 BLUMOON COMPLEX 65 AND 66 MG ROAD']},
#   'lastUpdate': '2025-06-03T10:21:53'},
#  {'chainCode': 'BW',
#   'iataCode': 'BLR',
#   'dupeId': 700144549,
#   'name': 'BW PREMIER LA MARVELLA',
#   'hotelId': 'BWBLR552',
#   'geoCode': {'latitude': 12.93756, 'longitude': 77.58279},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560011',
#    'cityName': 'BENGALURU',
#    'lines': ['1 14TH CROSS  SOUTH END CIRCLE']},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:16:09'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346306,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLR678',
#   'geoCode': {'latitude': 13.02247, 'longitude': 77.56128},
#   'address': {'countryCode': 'IN',
#    'postalCode': '571108',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:14:53'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 502346459,
#   'name': 'TEST1',
#   'hotelId': 'OIBLR3WT',
#   'geoCode': {'latitude': 12.95388, 'longitude': 77.68965},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560037',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BELLANDUR']},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-07T09:03:44'},
#  {'chainCode': 'AL',
#   'iataCode': 'BLR',
#   'dupeId': 700151103,
#   'name': 'ALOFT BENGALURU WHITEFIELD',
#   'hotelId': 'ALBLR275',
#   'geoCode': {'latitude': 12.98623, 'longitude': 77.73157},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BENGALURU',
#    'lines': ['17C SADARAMANGALA ROAD', 'OFF WHITEFIELD MAIN ROAD OPPOS']},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-08-11T06:16:25'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502346309,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLRPOR',
#   'geoCode': {'latitude': 13.02247, 'longitude': 77.56128},
#   'address': {'countryCode': 'IN',
#    'postalCode': '571108',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST']},
#   'lastUpdate': '2025-08-12T10:20:01'},
#  {'chainCode': 'IQ',
#   'iataCode': 'BLR',
#   'dupeId': 700117815,
#   'name': 'ROYAL ORCHID SUITES BANGALORE',
#   'hotelId': 'IQBLRROS',
#   'geoCode': {'latitude': 12.96031, 'longitude': 77.74748},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560066',
#    'cityName': 'BANGALORE',
#    'lines': ['WHITEFIELD MAIN ROAD',
#     'ANNEXE OF VASWANI PINNACLE,NEAR FORUM VALUE MALL']},
#   'lastUpdate': '2025-06-03T10:16:45'},
#  {'chainCode': 'UZ',
#   'iataCode': 'BLR',
#   'dupeId': 700145865,
#   'name': 'LORDS PLAZA BENGALURU',
#   'hotelId': 'UZBLRLPB',
#   'geoCode': {'latitude': 12.8577, 'longitude': 77.66243},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560100',
#    'cityName': 'BANGALORE',
#    'lines': ['26-A  HOSUR ROAD  OPPOSITE INFOSYS',
#     'ELECTRONIC CITY  PHASE 1']},
#   'lastUpdate': '2025-06-03T10:18:06'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502345601,
#   'name': 'TEST PROPERTY',
#   'hotelId': 'HNBLRCNN',
#   'geoCode': {'latitude': 12.0, 'longitude': 14.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '586932',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['TEST ADDRESS']},
#   'lastUpdate': '2025-10-07T09:03:18'},
#  {'chainCode': 'EX',
#   'iataCode': 'BLR',
#   'dupeId': 502374673,
#   'name': 'TEST PROPERTY EX1',
#   'hotelId': 'EXBLRDTB',
#   'geoCode': {'latitude': 13.00576, 'longitude': 77.62492},
#   'address': {'countryCode': 'IN',
#    'postalCode': '123456',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['STREET10 1']},
#   'lastUpdate': '2025-10-09T09:04:00'},
#  {'chainCode': 'IL',
#   'iataCode': 'BLR',
#   'dupeId': 700054750,
#   'name': 'NAHARS HERITAGE HOTEL',
#   'hotelId': 'ILBLR024',
#   'geoCode': {'latitude': 12.98138, 'longitude': 77.57528},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['14 ST MARKS ROAD']},
#   'lastUpdate': '2025-06-03T10:19:07'},
#  {'chainCode': 'VP',
#   'iataCode': 'BLR',
#   'dupeId': 502345474,
#   'name': 'TEST PROPERTY FOR RESALYS FOR CERTIFICAT',
#   'hotelId': 'VPBLRAH8',
#   'geoCode': {'latitude': 12.91458, 'longitude': 77.59954},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560078',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['BANGALORE ONE']},
#   'lastUpdate': '2025-10-08T09:00:11'},
#  {'chainCode': 'HN',
#   'iataCode': 'BLR',
#   'dupeId': 502372873,
#   'name': 'TEST BLR',
#   'hotelId': 'HNBLRRRF',
#   'geoCode': {'latitude': 0.0, 'longitude': 0.0},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560072',
#    'stateCode': 'KA',
#    'cityName': 'Bengaluru',
#    'lines': ['MYSORE']},
#   'lastUpdate': '2025-08-12T10:21:02'},
#  {'chainCode': 'WV',
#   'iataCode': 'BLR',
#   'dupeId': 700172702,
#   'name': 'CITRUS BENGALURU',
#   'hotelId': 'WVBLR273',
#   'geoCode': {'latitude': 12.92506, 'longitude': 77.67514},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560103',
#    'cityName': 'BENGALURU',
#    'lines': ['80 02 MARATHAHALLI SARJAPUR', 'BELLANDUR']},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:08'},
#  {'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700042679,
#   'name': 'THECAPITOL BANGALORE',
#   'hotelId': 'YXBLRR10',
#   'geoCode': {'latitude': 12.98206, 'longitude': 77.59433},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560001',
#    'cityName': 'BANGALORE',
#    'lines': ['RAJBHAVAN ROAD 3']},
#   'lastUpdate': '2025-06-03T10:18:46'}]

# %%
search_hotels_by_area_result = tools.search_hotels_by_area.invoke({
    "latitude": 48.8582599,
    "longitude": 2.2945006,
    # "radius": 3
})
search_hotels_by_area_result
# Out:
# 🏨 Searching for hotels near (48.8582599, 2.2945006) within 2KM...
# 🏨 Searching for hotels near lat:48.8582599, lon:2.2945006 within a 2KM radius.
# [{'chainCode': 'HN',
#   'iataCode': 'PAR',
#   'dupeId': 502389673,
#   'name': 'HOTEL HOUSE OF TRAVEL',
#   'hotelId': 'HNPARIPA',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'lastUpdate': '2025-08-01T09:00:19'},
#  {'chainCode': 'HN',
#   'iataCode': 'PAR',
#   'dupeId': 502389666,
#   'name': 'HN TEST PROPERTY FOR HCR EVACUATION REHE',
#   'hotelId': 'HNPARJLC',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'lastUpdate': '2025-08-01T09:00:19'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389769,
#   'name': 'HN TEST PROPERTY FOR HCR EVACUATION REHE',
#   'hotelId': 'OIPAR4I4',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:39:26'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389665,
#   'name': 'LK TEST PROPERTY1 FOR PROPERTY SEARCH FU',
#   'hotelId': 'OIPAR47X',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:38:11'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389679,
#   'name': 'HN TEST PROPERTY FOR HCR EVACUATION REHE',
#   'hotelId': 'OIPAR1PK',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:25:48'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389770,
#   'name': 'BEST HOTEL BY HOUSE OF TRAVEL',
#   'hotelId': 'OIPAR6AK',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:45:37'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389732,
#   'name': 'HN TEST PROPERTY FOR HCR EVACUATION REHE',
#   'hotelId': 'OIPAR8UD',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:51:25'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502374501,
#   'name': 'LK TEST PROPERTY FOR DRI CLOUD MIGRATION',
#   'hotelId': 'OIPAR07J',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:17:05'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389863,
#   'name': 'LK TEST PROPERTY FOR COM VALIDATIONS',
#   'hotelId': 'OIPAR0Y7',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:21:22'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502390021,
#   'name': 'LK TEST PROPERTY FOR REGULAT AUTOMATED T',
#   'hotelId': 'OIPAR228',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'Paris',
#    'lines': ['18 AVE DE SUFFREN', 'ENTRéE AU 22 RUE JEAN REY']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:28:18'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389814,
#   'name': 'LK TEST PROPERTY FOR HCR CLOUD MIGRATION',
#   'hotelId': 'OIPAR4RB',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'Paris',
#    'lines': ['18 AVE DE SUFFREN', 'ENTRéE AU 22 RUE JEAN REY']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T09:23:30'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389811,
#   'name': 'LK TEST PROPERTY FOR HCR CLOUD MIGRATION',
#   'hotelId': 'OIPAR7FI',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:49:19'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389808,
#   'name': 'LK TEST PROPERTY FOR HCR CLOUD MIGRATION',
#   'hotelId': 'OIPAR3KR',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '47400',
#    'cityName': 'Paris',
#    'lines': ['2314 STANLEY RD', 'SCHOEMAN ST']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:34:46'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 502389995,
#   'name': 'LK TEST PROPERTY FOR REGULAT AUTOMATED T',
#   'hotelId': 'OIPAR4O8',
#   'geoCode': {'latitude': 48.8584, 'longitude': 2.2945},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'Paris',
#    'lines': ['18 AVE DE SUFFREN', 'ENTRéE AU 22 RUE JEAN REY']},
#   'distance': {'value': 0.01, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-10-17T07:40:40'},
#  {'chainCode': 'PU',
#   'iataCode': 'PAR',
#   'dupeId': 700028589,
#   'name': 'PULLMAN PARIS TOUR EIFFEL',
#   'hotelId': 'PUPARTOU',
#   'geoCode': {'latitude': 48.85598, 'longitude': 2.29321},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['18 AVENUE DE SUFFREN']},
#   'distance': {'value': 0.26, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:16:56'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092063,
#   'name': 'HOTEL EIFFEL RIVE GAUCHE',
#   'hotelId': 'YXPAR348',
#   'geoCode': {'latitude': 48.85746, 'longitude': 2.30236},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DU GROS CAILLOU']},
#   'distance': {'value': 0.58, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:55'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700038153,
#   'name': 'EIFFEL SEINE',
#   'hotelId': 'UIPARGRE',
#   'geoCode': {'latitude': 48.85408, 'longitude': 2.2894},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['3 BOULEVARD DE GRENELLE']},
#   'distance': {'value': 0.59, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:00'},
#  {'chainCode': 'SG',
#   'iataCode': 'PAR',
#   'dupeId': 700144200,
#   'name': 'SHANGRI LA PARIS',
#   'hotelId': 'SGPARSHP',
#   'geoCode': {'latitude': 48.86421, 'longitude': 2.29351},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['10 AVENUE D IENA']},
#   'distance': {'value': 0.66, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:33'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700137581,
#   'name': 'DE LA TOUR EIFFEL',
#   'hotelId': 'HSORYABU',
#   'geoCode': {'latitude': 48.85681, 'longitude': 2.30397},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ["17, RUE DE L'EXPOSITION"]},
#   'distance': {'value': 0.71, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:04'},
#  {'chainCode': 'DS',
#   'iataCode': 'PAR',
#   'dupeId': 700043896,
#   'name': 'HOTEL SEZZ PARIS',
#   'hotelId': 'DSPARSEZ',
#   'geoCode': {'latitude': 48.85654, 'longitude': 2.28496},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['6 AVENUE FREMIET']},
#   'distance': {'value': 0.72, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:58'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700061053,
#   'name': 'HOTEL MAISON FL',
#   'hotelId': 'UIPARPAS',
#   'geoCode': {'latitude': 48.85864, 'longitude': 2.28415},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DE LA TOUR']},
#   'distance': {'value': 0.75, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:01'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700025209,
#   'name': 'HOTEL LE MARQUIS',
#   'hotelId': 'FGPARDUP',
#   'geoCode': {'latitude': 48.8517, 'longitude': 2.29768},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['15 RUE DUPLEIX']},
#   'distance': {'value': 0.76, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:43'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347191,
#   'name': 'HOTEL LE MARQUIS EIFFEL',
#   'hotelId': 'VPPAR050',
#   'geoCode': {'latitude': 48.85166, 'longitude': 2.29781},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'Paris',
#    'lines': ['15, RUE DUPLEX']},
#   'distance': {'value': 0.77, 'unit': 'KM'},
#   'lastUpdate': '2025-10-07T09:03:48'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092127,
#   'name': 'HOTEL PASSY EIFFEL',
#   'hotelId': 'YXPARHPE',
#   'geoCode': {'latitude': 48.85842, 'longitude': 2.28345},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['10 RUE DE PASSY']},
#   'distance': {'value': 0.8, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:58'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700019804,
#   'name': 'BEST WESTERN AU TROCADERO',
#   'hotelId': 'BWPAR261',
#   'geoCode': {'latitude': 48.86352, 'longitude': 2.28673},
#   'address': {'countryCode': 'FR',
#    'postalCode': 'FR75116',
#    'cityName': 'PARIS',
#    'lines': ['3 AVENUE RAYMOND-POINCARE']},
#   'distance': {'value': 0.81, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:17:14'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700048871,
#   'name': 'EXCLUSIVE V. DES AMBASSADEURS',
#   'hotelId': 'EUPARVAM',
#   'geoCode': {'latitude': 48.86529, 'longitude': 2.2905},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DU BOUQUET DE LONGCHAMPS']},
#   'distance': {'value': 0.83, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092065,
#   'name': 'LA SERRE HOTEL',
#   'hotelId': 'YXPARHLS',
#   'geoCode': {'latitude': 48.8575, 'longitude': 2.30592},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['24 BIS RUE CLER']},
#   'distance': {'value': 0.84, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'IW',
#   'iataCode': 'PAR',
#   'dupeId': 700072174,
#   'name': 'HOTEL GAVARNI',
#   'hotelId': 'IWPAR302',
#   'geoCode': {'latitude': 48.85852, 'longitude': 2.28288},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['5 RUE GAVARNI']},
#   'distance': {'value': 0.85, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:20:01'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700025210,
#   'name': 'DU CADRAN',
#   'hotelId': 'ACPAR478',
#   'geoCode': {'latitude': 48.85647, 'longitude': 2.30592},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['10, RUE DU CHAMP DE MARS']},
#   'distance': {'value': 0.85, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:50'},
#  {'chainCode': 'AZ',
#   'iataCode': 'PAR',
#   'dupeId': 700010914,
#   'name': 'CITADINES ARC DE TRIOMPHE',
#   'hotelId': 'AZPARKLE',
#   'geoCode': {'latitude': 48.86491, 'longitude': 2.28853},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['81 AVENUE KLEBER']},
#   'distance': {'value': 0.86, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:27'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092068,
#   'name': 'HOTEL MALAR',
#   'hotelId': 'YXPARMAL',
#   'geoCode': {'latitude': 48.86019, 'longitude': 2.30602},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['29 RUE MALAR']},
#   'distance': {'value': 0.87, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700054942,
#   'name': 'MERCURE PARIS TOUR EIFFEL 4*',
#   'hotelId': 'RTPAREIF',
#   'geoCode': {'latitude': 48.85052, 'longitude': 2.29245},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['64 BOULEVARD DE GRENELLE']},
#   'distance': {'value': 0.87, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:22',
#   'retailing': {'sponsorship': {'isSponsored': True}}},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092059,
#   'name': 'DE LA TULIPE HOTEL',
#   'hotelId': 'YXPARTUL',
#   'geoCode': {'latitude': 48.85998, 'longitude': 2.30613},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['33 RUE MALAR']},
#   'distance': {'value': 0.87, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700158068,
#   'name': 'RELAIS ST CHARLES',
#   'hotelId': 'YXPARREL',
#   'geoCode': {'latitude': 48.85029, 'longitude': 2.29332},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['72 BOULEVARD DE GRENELLE']},
#   'distance': {'value': 0.89, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700024347,
#   'name': 'TIMHOTEL TOUR EIFFEL',
#   'hotelId': 'UIPARDUP',
#   'geoCode': {'latitude': 48.85008, 'longitude': 2.29235},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['11 RUE JUGE']},
#   'distance': {'value': 0.92, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:00'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700031282,
#   'name': 'EXCLUSIVE HOTEL BEAUGRENELLE TOUR EIFFEL',
#   'hotelId': 'EUPAR402',
#   'geoCode': {'latitude': 48.85028, 'longitude': 2.29043},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PAR',
#    'lines': ['19 RUE VIALA']},
#   'distance': {'value': 0.93, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700045994,
#   'name': 'HOTEL LE WALT',
#   'hotelId': 'FGPAR123',
#   'geoCode': {'latitude': 48.85485, 'longitude': 2.3065},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['37 AVENUE DE LA MOTTE PICQUET']},
#   'distance': {'value': 0.95, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:42'},
#  {'chainCode': 'IW',
#   'iataCode': 'PAR',
#   'dupeId': 700057503,
#   'name': '7 EIFFEL',
#   'hotelId': 'IWPAR819',
#   'geoCode': {'latitude': 48.85825, 'longitude': 2.30767},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['17 BIS RUE AMELIE']},
#   'distance': {'value': 0.96, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:20:01'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700030697,
#   'name': 'EUROPE HOTEL',
#   'hotelId': 'YXPARH33',
#   'geoCode': {'latitude': 48.84953, 'longitude': 2.29682},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['103 BD DE GRENELLE']},
#   'distance': {'value': 0.98, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700007524,
#   'name': 'HOTEL FRANCE EIFFEL',
#   'hotelId': 'YXPARH07',
#   'geoCode': {'latitude': 48.85005, 'longitude': 2.28849},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['8, RUE SAINT CHARLES']},
#   'distance': {'value': 1.01, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700060230,
#   'name': 'HOTEL EIFFEL SAINT CHARLES',
#   'hotelId': 'EUPAREFF',
#   'geoCode': {'latitude': 48.84984, 'longitude': 2.28843},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['37 RUE SAINT CHARLES']},
#   'distance': {'value': 1.03, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700005290,
#   'name': 'DERBY EIFFEL',
#   'hotelId': 'HSORYAAM',
#   'geoCode': {'latitude': 48.85372, 'longitude': 2.30707},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['5, AVENUE DUQUESNE']},
#   'distance': {'value': 1.04, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:04'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700051487,
#   'name': 'EXCLUSIVE SPLENDID EIFFEL',
#   'hotelId': 'EUPAR838',
#   'geoCode': {'latitude': 48.85391, 'longitude': 2.30723},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['29 AVENUE DE TOURVILLE']},
#   'distance': {'value': 1.04, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700054614,
#   'name': 'HOTEL MONTAIGNE',
#   'hotelId': 'FGPARHMO',
#   'geoCode': {'latitude': 48.86551, 'longitude': 2.30385},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['6 AVENUE MONTAIGNE']},
#   'distance': {'value': 1.05, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:43'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700053317,
#   'name': 'ADAGIO ACCESS PARIS EIFFEL',
#   'hotelId': 'RTPARADC',
#   'geoCode': {'latitude': 48.84963, 'longitude': 2.28829},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['43 RUE SAINT CHARLES']},
#   'distance': {'value': 1.06, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:23'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 501528354,
#   'name': 'LE CINQ CODET PARIS',
#   'hotelId': 'YXPARLCC',
#   'geoCode': {'latitude': 48.85509, 'longitude': 2.30825},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['5 RUE LOUIS CODET']},
#   'distance': {'value': 1.06, 'unit': 'KM'},
#   'lastUpdate': '2025-10-09T09:03:39'},
#  {'chainCode': 'RD',
#   'iataCode': 'PAR',
#   'dupeId': 700013754,
#   'name': 'RADISSON BLU LE DOKHANS TROCAD',
#   'hotelId': 'RDPAR958',
#   'geoCode': {'latitude': 48.86624, 'longitude': 2.28634},
#   'address': {'countryCode': 'FR',
#    'postalCode': 'F75116',
#    'cityName': 'PARIS',
#    'lines': ['117 RUE LAURISTON']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'masterChainCode': 'CW',
#   'lastUpdate': '2025-06-03T10:17:14'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700020647,
#   'name': 'BW PREMIER TROCADERO LA TOUR',
#   'hotelId': 'BWPAR631',
#   'geoCode': {'latitude': 48.85808, 'longitude': 2.27986},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['5 BIS RUE MASSENETT']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:16:18'},
#  {'chainCode': 'AZ',
#   'iataCode': 'PAR',
#   'dupeId': 700032820,
#   'name': 'CITADINES TOUR EIFFEL PARIS',
#   'hotelId': 'AZPAROEI',
#   'geoCode': {'latitude': 48.8489, 'longitude': 2.29806},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['132, BOULEVARD DE GRENELLE']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:27'},
#  {'chainCode': 'VP',
#   'iataCode': 'AGF',
#   'dupeId': 502347192,
#   'name': 'HOTEL LE TOURVILLE',
#   'hotelId': 'VPAGF054',
#   'geoCode': {'latitude': 48.85421, 'longitude': 2.30783},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'Agen',
#    'lines': ['16, AVENUE DE TOURVILLE']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'lastUpdate': '2025-10-01T09:00:21'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700062201,
#   'name': 'HOTEL LE TOURVILLE EIFFEL',
#   'hotelId': 'FGPARLTH',
#   'geoCode': {'latitude': 48.85412, 'longitude': 2.30778},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['16 AVENUE DE TOURVILLE']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:43'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700072171,
#   'name': 'HOTEL LE HAMEAU DE PASSY',
#   'hotelId': 'YXPARHHL',
#   'geoCode': {'latitude': 48.85781, 'longitude': 2.27979},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['48  RUE DE PASSY']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700054638,
#   'name': 'WINDSOR HOME',
#   'hotelId': 'HSORYAFC',
#   'geoCode': {'latitude': 48.86051, 'longitude': 2.28016},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['3 RUE VITAL']},
#   'distance': {'value': 1.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:05'},
#  {'chainCode': 'WV',
#   'iataCode': 'PAR',
#   'dupeId': 700054634,
#   'name': 'AU PACIFIC',
#   'hotelId': 'WVPAR168',
#   'geoCode': {'latitude': 48.84868, 'longitude': 2.29185},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['11 RUE FONDARY']},
#   'distance': {'value': 1.08, 'unit': 'KM'},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:25'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700026898,
#   'name': 'WALDORF TROCADERO HOTEL',
#   'hotelId': 'UIPARWTH',
#   'geoCode': {'latitude': 48.86715, 'longitude': 2.2877},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['97 RUE LAURISTON']},
#   'distance': {'value': 1.1, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:02'},
#  {'chainCode': 'HS',
#   'iataCode': 'PAR',
#   'dupeId': 700092125,
#   'name': 'SAPHIR GRENELLE',
#   'hotelId': 'HSPARAZY',
#   'geoCode': {'latitude': 48.84841, 'longitude': 2.29703},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['10 RUE DE COMMERCE']},
#   'distance': {'value': 1.11, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:02'},
#  {'chainCode': 'AZ',
#   'iataCode': 'PAR',
#   'dupeId': 700011796,
#   'name': 'CITADINES TROCADERO PARIS',
#   'hotelId': 'AZPAR310',
#   'geoCode': {'latitude': 48.86641, 'longitude': 2.28571},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['29 BIS RUE SAINT DIDIER']},
#   'distance': {'value': 1.11, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:27'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700133748,
#   'name': 'HOTEL LE PAVILLON',
#   'hotelId': 'YXPARHLP',
#   'geoCode': {'latitude': 48.85987, 'longitude': 2.30957},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['54 RUE SAINT DOMINQUE']},
#   'distance': {'value': 1.11, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'LE',
#   'iataCode': 'PAR',
#   'dupeId': 700024153,
#   'name': 'HOTEL PLAZA TOUR EIFFEL',
#   'hotelId': 'LEPARPTE',
#   'geoCode': {'latitude': 48.86443, 'longitude': 2.28222},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['32 RUE GREUZAE']},
#   'distance': {'value': 1.13, 'unit': 'KM'},
#   'masterChainCode': 'PV',
#   'lastUpdate': '2025-06-03T10:20:31'},
#  {'chainCode': 'PH',
#   'iataCode': 'PAR',
#   'dupeId': 700029554,
#   'name': 'LA TREMOILLE PREFERRED HOTELS',
#   'hotelId': 'PHPARLTE',
#   'geoCode': {'latitude': 48.86687, 'longitude': 2.30275},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['14 RUE DE LA TREMOILLE']},
#   'distance': {'value': 1.13, 'unit': 'KM'},
#   'masterChainCode': 'PV',
#   'lastUpdate': '2025-06-03T10:16:45'},
#  {'chainCode': 'SM',
#   'iataCode': 'PAR',
#   'dupeId': 700029552,
#   'name': 'MELIA ROYAL ALMA',
#   'hotelId': 'SMPARALM',
#   'geoCode': {'latitude': 48.86554, 'longitude': 2.30533},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['35 RUE JEAN GOUJON']},
#   'distance': {'value': 1.13, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:38'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700054636,
#   'name': 'EXCLUSIVE MARCEAU CHAMPS ELYSEES',
#   'hotelId': 'EUPAR469',
#   'geoCode': {'latitude': 48.86815, 'longitude': 2.29875},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['37, AVENUE MARCEAU']},
#   'distance': {'value': 1.14, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'HS',
#   'iataCode': 'PAR',
#   'dupeId': 700053350,
#   'name': 'EXPOSITION EIFFEL',
#   'hotelId': 'HSPARAUT',
#   'geoCode': {'latitude': 48.84891, 'longitude': 2.28769},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['42 BIS RUE DU THEATRE']},
#   'distance': {'value': 1.15, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:02'},
#  {'chainCode': 'RD',
#   'iataCode': 'PAR',
#   'dupeId': 700135966,
#   'name': 'RADISSON BLU LE METROPOLITAN',
#   'hotelId': 'RDPAR956',
#   'geoCode': {'latitude': 48.86552, 'longitude': 2.28316},
#   'address': {'countryCode': 'FR',
#    'postalCode': 'F75116',
#    'cityName': 'PARIS',
#    'lines': ['10 PLACE DE MEXICO']},
#   'distance': {'value': 1.15, 'unit': 'KM'},
#   'masterChainCode': 'CW',
#   'lastUpdate': '2025-06-03T10:17:14'},
#  {'chainCode': 'BR',
#   'iataCode': 'PAR',
#   'dupeId': 700024753,
#   'name': 'RENAISSANCE LE PARC TROCADERO',
#   'hotelId': 'BRPARSPB',
#   'geoCode': {'latitude': 48.86714, 'longitude': 2.28594},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['55-57 AVENUE RAYMOND POINCARE']},
#   'distance': {'value': 1.17, 'unit': 'KM'},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-09-29T06:04:35'},
#  {'chainCode': 'WW',
#   'iataCode': 'PAR',
#   'dupeId': 700045819,
#   'name': 'HOTEL DE SERS CHAMPS ELYSEES',
#   'hotelId': 'WWPARDES',
#   'geoCode': {'latitude': 48.86809, 'longitude': 2.30049},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['41 AVENUE PIERRE 1ER DE SERBIE']},
#   'distance': {'value': 1.17, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:18:21'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700058807,
#   'name': 'EXCLUSIVE SEVIGNE ELYSEES',
#   'hotelId': 'EUPAR107',
#   'geoCode': {'latitude': 48.8688, 'longitude': 2.29242},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DE BELLOY']},
#   'distance': {'value': 1.18, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700029526,
#   'name': 'HOTEL LES HAUTS DE PASSY',
#   'hotelId': 'YXPAR031',
#   'geoCode': {'latitude': 48.85723, 'longitude': 2.27832},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['37 RUE DE L ANNONCIATION']},
#   'distance': {'value': 1.19, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'CH',
#   'iataCode': 'PAR',
#   'dupeId': 700004463,
#   'name': 'HOTEL AMBASSADE',
#   'hotelId': 'CHPARH24',
#   'geoCode': {'latitude': 48.86835, 'longitude': 2.28898},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['79 RUE DE LAURISTON']},
#   'distance': {'value': 1.19, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:22'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700007095,
#   'name': 'EXCLUSIVE HOTEL ELYSEES REGENCIA',
#   'hotelId': 'EUPAR361',
#   'geoCode': {'latitude': 48.86867, 'longitude': 2.29854},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['41 AVENUE MARCEAU']},
#   'distance': {'value': 1.19, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700092057,
#   'name': 'HOTEL DE FRANCE INVALIDES',
#   'hotelId': 'FGPARAKK',
#   'geoCode': {'latitude': 48.85348, 'longitude': 2.30932},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['102, BOULEVARD LA TOUR MAUBOURG']},
#   'distance': {'value': 1.2, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:42'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700007093,
#   'name': 'HOTEL ELYSEES BASSANO',
#   'hotelId': 'UIPARHEB',
#   'geoCode': {'latitude': 48.86899, 'longitude': 2.29732},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['24 RUE DE BASSANO']},
#   'distance': {'value': 1.21, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:00'},
#  {'chainCode': 'OI',
#   'iataCode': 'PAR',
#   'dupeId': 700029523,
#   'name': 'HOTEL WEST END',
#   'hotelId': 'OIPARWES',
#   'geoCode': {'latitude': 48.8673, 'longitude': 2.30376},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'Paris',
#    'lines': ['7 RUE CLEMENT MAROT']},
#   'distance': {'value': 1.21, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:20:08'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347179,
#   'name': 'RELAIS & CHATEAUX CAZAUDEHORE LA FORESTI',
#   'hotelId': 'VPPAR020',
#   'geoCode': {'latitude': 48.85234, 'longitude': 2.28043},
#   'address': {'countryCode': 'FR',
#    'postalCode': '78100',
#    'cityName': 'Paris',
#    'lines': ['1, AVENUE KENNEDY']},
#   'distance': {'value': 1.22, 'unit': 'KM'},
#   'lastUpdate': '2025-10-07T09:03:48'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 501691538,
#   'name': 'APPARTEMENTS HELZEAR CHAMPS ELYSEES',
#   'hotelId': 'ACPARF33',
#   'geoCode': {'latitude': 48.86914, 'longitude': 2.29826},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['49 AVENUE MARCEAU']},
#   'distance': {'value': 1.24, 'unit': 'KM'},
#   'lastUpdate': '2025-10-09T09:03:52'},
#  {'chainCode': 'ON',
#   'iataCode': 'NYO',
#   'dupeId': 502177550,
#   'name': 'SUNLIGHT HOTEL CONFERENCE AND SPA',
#   'hotelId': 'ONNYOSUN',
#   'geoCode': {'latitude': 48.84978, 'longitude': 2.28284},
#   'address': {'countryCode': 'SE',
#    'postalCode': '61138',
#    'cityName': 'SWEDEN',
#    'lines': ['NYTORGET 7', 'NYKOPING']},
#   'distance': {'value': 1.27, 'unit': 'KM'},
#   'lastUpdate': '2025-10-07T09:03:43'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700027695,
#   'name': 'NOVOTEL PARIS CENTRE TOUR EIFFEL',
#   'hotelId': 'RTPAR001',
#   'geoCode': {'latitude': 48.84978, 'longitude': 2.28284},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['61 QUAI DE GRENELLE']},
#   'distance': {'value': 1.27, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:23'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700054656,
#   'name': 'HTL ANGLETERRE ETOI',
#   'hotelId': 'YXPAR317',
#   'geoCode': {'latitude': 48.86916, 'longitude': 2.28901},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['21 RUE COPERNIC']},
#   'distance': {'value': 1.27, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:55'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700092119,
#   'name': 'IBIS PARIS TOUR EIFFEL',
#   'hotelId': 'RTPARCAM',
#   'geoCode': {'latitude': 48.84765, 'longitude': 2.30145},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['2 RUE CAMBRONNE', 'EX HOTEL ARCADE']},
#   'distance': {'value': 1.28, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:22'},
#  {'chainCode': 'FS',
#   'iataCode': 'PAR',
#   'dupeId': 700007506,
#   'name': 'FOUR SEASONS GEORGE V PARIS',
#   'hotelId': 'FSPAR837',
#   'geoCode': {'latitude': 48.86903, 'longitude': 2.30083},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['31 AVE GEORGE V']},
#   'distance': {'value': 1.28, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:34'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700013914,
#   'name': 'BEST WESTERN HOTEL VICTOR HUGO',
#   'hotelId': 'BWPAR503',
#   'geoCode': {'latitude': 48.86923, 'longitude': 2.28864},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['19 RUE COPERNIC']},
#   'distance': {'value': 1.29, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:16:02'},
#  {'chainCode': 'PH',
#   'iataCode': 'PAR',
#   'dupeId': 700008959,
#   'name': 'HOTEL KEPPLER PREFERRED BOUTIQ',
#   'hotelId': 'PHPARHKP',
#   'geoCode': {'latitude': 48.86976, 'longitude': 2.29728},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['12 RUE KEPLER']},
#   'distance': {'value': 1.29, 'unit': 'KM'},
#   'masterChainCode': 'PV',
#   'lastUpdate': '2025-06-03T10:16:45'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700058818,
#   'name': 'PERSHING HALL',
#   'hotelId': 'FGPAR955',
#   'geoCode': {'latitude': 48.86909, 'longitude': 2.30222},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['49 RUE PIERRE CHARRON']},
#   'distance': {'value': 1.33, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:42'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700158028,
#   'name': 'FIRST HOTEL PARIS TOUR EIFFEL',
#   'hotelId': 'ACPARD37',
#   'geoCode': {'latitude': 48.84751, 'longitude': 2.30256},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['2 BOULEVARD GARIBALDI']},
#   'distance': {'value': 1.33, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:32'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700027610,
#   'name': 'MERCURE PARIS CHAMPS ELYSEES',
#   'hotelId': 'RTPARCHA',
#   'geoCode': {'latitude': 48.86998, 'longitude': 2.29068},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['51 RUE LAURISTON']},
#   'distance': {'value': 1.33, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:22'},
#  {'chainCode': 'PH',
#   'iataCode': 'PAR',
#   'dupeId': 700143982,
#   'name': 'VILLA HOTEL MAJESTIC PREFERRED',
#   'hotelId': 'PHPARVHM',
#   'geoCode': {'latitude': 48.87025, 'longitude': 2.29382},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['30 RUE LA PEROUSER']},
#   'distance': {'value': 1.33, 'unit': 'KM'},
#   'masterChainCode': 'PV',
#   'lastUpdate': '2025-06-03T10:16:45'},
#  {'chainCode': 'WW',
#   'iataCode': 'PAR',
#   'dupeId': 700058049,
#   'name': 'HOTEL CLARIDGE',
#   'hotelId': 'WWPARCLA',
#   'geoCode': {'latitude': 48.86859, 'longitude': 2.30378},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['37 RUE FRANCOIS 1ER']},
#   'distance': {'value': 1.33, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:18:21'},
#  {'chainCode': 'IC',
#   'iataCode': 'PAR',
#   'dupeId': 700092074,
#   'name': 'INTERCONTINENTAL PARIS AVE MAR',
#   'hotelId': 'ICPAR70E',
#   'geoCode': {'latitude': 48.87007, 'longitude': 2.29804},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['64 MARCEAU']},
#   'distance': {'value': 1.34, 'unit': 'KM'},
#   'masterChainCode': '6C',
#   'lastUpdate': '2025-06-03T10:20:01'},
#  {'chainCode': 'LE',
#   'iataCode': 'PAR',
#   'dupeId': 700038399,
#   'name': 'HOTEL POWERS',
#   'hotelId': 'LEPARPOW',
#   'geoCode': {'latitude': 48.86911, 'longitude': 2.30295},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['52 RUE FRANCOIS 1ER']},
#   'distance': {'value': 1.35, 'unit': 'KM'},
#   'masterChainCode': 'PV',
#   'lastUpdate': '2025-06-03T10:20:31'},
#  {'chainCode': 'CH',
#   'iataCode': 'PAR',
#   'dupeId': 700056602,
#   'name': 'HOTEL ALIZE GRENELLE TOUR EIFFEL',
#   'hotelId': 'CHPAR041',
#   'geoCode': {'latitude': 48.84674, 'longitude': 2.28777},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['87 AVENUE EMILE ZOLA']},
#   'distance': {'value': 1.37, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:19'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700033056,
#   'name': 'BEAUGRENELLE ST-CHARLES TOUR',
#   'hotelId': 'YXPAR032',
#   'geoCode': {'latitude': 48.84721, 'longitude': 2.28592},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['82 RUE SAINT-CHARLES']},
#   'distance': {'value': 1.38, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700092130,
#   'name': 'VILLA GLAMOUR TOUR EIFFEL',
#   'hotelId': 'ACPAR455',
#   'geoCode': {'latitude': 48.86447, 'longitude': 2.27803},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['85 RUE DE LA POMPE']},
#   'distance': {'value': 1.39, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:59'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700058497,
#   'name': 'CYRNOS',
#   'hotelId': 'ACPAR458',
#   'geoCode': {'latitude': 48.86447, 'longitude': 2.27803},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75002',
#    'cityName': 'PARIS',
#    'lines': ['154, RUE MONTMARTRE']},
#   'distance': {'value': 1.39, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700054617,
#   'name': 'BEST WESTERN FOLKESTONE OPERA',
#   'hotelId': 'BWPAR203',
#   'geoCode': {'latitude': 48.87043, 'longitude': 2.29981},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['9 RUE CASTELLANE']},
#   'distance': {'value': 1.41, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:17:29'},
#  {'chainCode': 'WV',
#   'iataCode': 'PAR',
#   'dupeId': 700024177,
#   'name': 'HOTEL MARIGNAN PARIS',
#   'hotelId': 'WVPARMGN',
#   'geoCode': {'latitude': 48.86842, 'longitude': 2.30628},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['12 RUE DE MARIGNAN']},
#   'distance': {'value': 1.42, 'unit': 'KM'},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:25'},
#  {'chainCode': 'PN',
#   'iataCode': 'PAR',
#   'dupeId': 700222607,
#   'name': 'THE PENINSULA PARIS',
#   'hotelId': 'PNPARTPP',
#   'geoCode': {'latitude': 48.87111, 'longitude': 2.29332},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['19 AVENUE KLEBER']},
#   'distance': {'value': 1.43, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:53'},
#  {'chainCode': 'LW',
#   'iataCode': 'PAR',
#   'dupeId': 700011610,
#   'name': 'HOTEL RAPHAEL',
#   'hotelId': 'LWPAR616',
#   'geoCode': {'latitude': 48.87127, 'longitude': 2.29343},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['17 AVENUE KLEBER']},
#   'distance': {'value': 1.45, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:46'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700150773,
#   'name': 'PLATINE HOTEL',
#   'hotelId': 'YXPARPLA',
#   'geoCode': {'latitude': 48.84748, 'longitude': 2.2831},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['20 RUE ING ROBERT KELLER']},
#   'distance': {'value': 1.46, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:00'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700079250,
#   'name': 'HOTEL EIFFEL SEGUR',
#   'hotelId': 'UIPAR614',
#   'geoCode': {'latitude': 48.84691, 'longitude': 2.3046},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['34 BOULEVARD GARIBALDI']},
#   'distance': {'value': 1.46, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:11'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347229,
#   'name': 'VILLA SAXE EIFFEL',
#   'hotelId': 'VPPAR158',
#   'geoCode': {'latitude': 48.84967, 'longitude': 2.30971},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'Paris',
#    'lines': ['9 VILLA DE SAXE']},
#   'distance': {'value': 1.46, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:22:02'},
#  {'chainCode': 'XL',
#   'iataCode': 'PAR',
#   'dupeId': 700007527,
#   'name': 'HOTEL FRANCOIS 1ER SUMMIT HOTE',
#   'hotelId': 'XLPAR1ER',
#   'geoCode': {'latitude': 48.871, 'longitude': 2.29963},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['7 RUE MAGELLAN']},
#   'distance': {'value': 1.46, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700029517,
#   'name': 'VILLA SAXE EIFFEL',
#   'hotelId': 'ACPARE68',
#   'geoCode': {'latitude': 48.84952, 'longitude': 2.30964},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['9 VILLA DE SAXE']},
#   'distance': {'value': 1.47, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:46'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700017921,
#   'name': 'ALYSS SAPHIR CAMBRONNE EIFFEL',
#   'hotelId': 'HSORYABF',
#   'geoCode': {'latitude': 48.84502, 'longitude': 2.29741},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['62, RUE CROIX DE NIVERT']},
#   'distance': {'value': 1.48, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:04'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502345895,
#   'name': "HOTEL BARRIERE LE FOUQUET'S PARIS",
#   'hotelId': 'VPPAR251',
#   'geoCode': {'latitude': 48.87113, 'longitude': 2.30118},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'Paris',
#    'lines': ['46, AVENUE GEORGE V']},
#   'distance': {'value': 1.51, 'unit': 'KM'},
#   'lastUpdate': '2025-10-07T09:03:49'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700006912,
#   'name': 'EXCLUSIVE DU BOIS ETOILE',
#   'hotelId': 'EUPARH05',
#   'geoCode': {'latitude': 48.87174, 'longitude': 2.29097},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['11 RUE DU DOME']},
#   'distance': {'value': 1.52, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'HS',
#   'iataCode': 'PAR',
#   'dupeId': 700129647,
#   'name': 'BALDI',
#   'hotelId': 'HSPARBOC',
#   'geoCode': {'latitude': 48.84658, 'longitude': 2.30552},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['42, BOULEVARD GARIBALDI']},
#   'distance': {'value': 1.52, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:02'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092116,
#   'name': 'HOTEL EIFFEL VILLA GARIBALDI',
#   'hotelId': 'YXPAREVG',
#   'geoCode': {'latitude': 48.84642, 'longitude': 2.30598},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['48 BOULEVARD GARIBALDI']},
#   'distance': {'value': 1.56, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:57'},
#  {'chainCode': 'LW',
#   'iataCode': 'PAR',
#   'dupeId': 700052136,
#   'name': 'HOTEL FOUQUETS BARRIERE',
#   'hotelId': 'LWPAR635',
#   'geoCode': {'latitude': 48.87169, 'longitude': 2.3008},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['46 AVENUE GEORGE V', '99 AVENUE DES CHAMPS ELYSEES']},
#   'distance': {'value': 1.56, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:46'},
#  {'chainCode': 'MC',
#   'iataCode': 'PAR',
#   'dupeId': 700009903,
#   'name': 'PARIS MARRIOTT CHAMPS-ELYSEES',
#   'hotelId': 'MCPARDTM',
#   'geoCode': {'latitude': 48.87077, 'longitude': 2.30446},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['70 AVE DES CHAMPS ELYSEES']},
#   'distance': {'value': 1.57, 'unit': 'KM'},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-09-15T06:26:34'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700044771,
#   'name': 'EXCLUSIVE BAILLI DE SUFFREN EIFFEL',
#   'hotelId': 'EUPAR873',
#   'geoCode': {'latitude': 48.84697, 'longitude': 2.30801},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['149 AVENUE DE SUFFREN']},
#   'distance': {'value': 1.59, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'XK',
#   'iataCode': 'PAR',
#   'dupeId': 501103408,
#   'name': 'THE RED HOTEL',
#   'hotelId': 'XKPAR101',
#   'geoCode': {'latitude': 48.86982, 'longitude': 2.30765},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75001',
#    'cityName': 'Paris',
#    'lines': ['25 AVENUE DES CHAMPS ELYSEES']},
#   'distance': {'value': 1.6, 'unit': 'KM'},
#   'lastUpdate': '2025-10-09T09:03:34'},
#  {'chainCode': 'MC',
#   'iataCode': 'PAR',
#   'dupeId': 502097828,
#   'name': 'TEST  MARRIOTT PARIS MCPARXXX',
#   'hotelId': 'MCPARXXX',
#   'geoCode': {'latitude': 48.87099, 'longitude': 2.30497},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['70 AVE DES CHAMPS ELYSEES']},
#   'distance': {'value': 1.61, 'unit': 'KM'},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-10-07T09:03:22'},
#  {'chainCode': 'MC',
#   'iataCode': 'PAR',
#   'dupeId': 502093056,
#   'name': 'TEST  MARRIOTT PARIS MCPARXXX',
#   'hotelId': 'MCPAR100',
#   'geoCode': {'latitude': 48.87099, 'longitude': 2.30497},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['70 AVE DES CHAMPS ELYSEES']},
#   'distance': {'value': 1.61, 'unit': 'KM'},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-07-21T09:00:13'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700006111,
#   'name': 'BEST WESTERN COLISEE',
#   'hotelId': 'BWPAR144',
#   'geoCode': {'latitude': 48.87023, 'longitude': 2.3071},
#   'address': {'countryCode': 'FR',
#    'postalCode': 'FR75008',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DU COLISEE', 'CHAMPS ELYSEES PARIS']},
#   'distance': {'value': 1.62, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:16:13'},
#  {'chainCode': 'WK',
#   'iataCode': 'PAR',
#   'dupeId': 700014208,
#   'name': 'WARWICK CHAMPS ELYSEES',
#   'hotelId': 'WKPARWAR',
#   'geoCode': {'latitude': 48.87181, 'longitude': 2.30314},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['5 RUE DE BERRI']},
#   'distance': {'value': 1.63, 'unit': 'KM'},
#   'masterChainCode': 'TC',
#   'lastUpdate': '2025-06-03T10:18:09'},
#  {'chainCode': 'HA',
#   'iataCode': 'PAR',
#   'dupeId': 700076374,
#   'name': 'ROYAL ELYSEES',
#   'hotelId': 'HAPARROY',
#   'geoCode': {'latitude': 48.87291, 'longitude': 2.29267},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['6 AVENUE VICTOR HUGO']},
#   'distance': {'value': 1.63, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:34'},
#  {'chainCode': 'LW',
#   'iataCode': 'PAR',
#   'dupeId': 700009251,
#   'name': 'HOTEL LANCASTER',
#   'hotelId': 'LWPAR615',
#   'geoCode': {'latitude': 48.87205, 'longitude': 2.30342},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['7 RUE DE BERRI, CHAMPS-ELYSEES']},
#   'distance': {'value': 1.66, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:46'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700165304,
#   'name': 'HOTEL DELARC',
#   'hotelId': 'YXPARHAB',
#   'geoCode': {'latitude': 48.87054, 'longitude': 2.30758},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
# ...
#   'geoCode': {'latitude': 48.87605, 'longitude': 2.29381},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['34 RUE VIALA']},
#   'distance': {'value': 1.98, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:09'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700021957,
#   'name': 'BALMORAL',
#   'hotelId': 'ACPARE72',
#   'geoCode': {'latitude': 48.87605, 'longitude': 2.29381},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DU GENERAL LANREZAC']},
#   'distance': {'value': 1.98, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:14'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347208,
#   'name': 'AMASTAN PARIS',
#   'hotelId': 'VPPAR102',
#   'geoCode': {'latitude': 48.87171, 'longitude': 2.31226},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'Paris',
#    'lines': ['34 RUE JEAN MERMOZ']},
#   'distance': {'value': 1.98, 'unit': 'KM'},
#   'lastUpdate': '2025-10-08T09:00:11'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700048467,
#   'name': 'ETOILE PARK HOTEL',
#   'hotelId': 'ACPARE24',
#   'geoCode': {'latitude': 48.87615, 'longitude': 2.29463},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['10 AVENUE MAC MAHON']},
#   'distance': {'value': 1.99, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:51'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700046494,
#   'name': 'STELLA ETOILE',
#   'hotelId': 'ACPAR130',
#   'geoCode': {'latitude': 48.87616, 'longitude': 2.2931},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['20 AVENUE CARNOT']},
#   'distance': {'value': 1.99, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:21'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700022931,
#   'name': 'HOTEL DU MOULIN',
#   'hotelId': 'ACPAR158',
#   'geoCode': {'latitude': 48.87616, 'longitude': 2.2931},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75018',
#    'cityName': 'PARIS',
#    'lines': ['3, RUE ARISTIDE BRUANT']},
#   'distance': {'value': 1.99, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700092064,
#   'name': 'EMPEREUR',
#   'hotelId': 'ACPAR147',
#   'geoCode': {'latitude': 48.87616, 'longitude': 2.2931},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['2 RUE CHEVERT']},
#   'distance': {'value': 1.99, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:05'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347184,
#   'name': 'HOTEL LE 123 ELYSEES',
#   'hotelId': 'VPPAR034',
#   'geoCode': {'latitude': 48.87313, 'longitude': 2.30973},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'Paris',
#    'lines': ['123, RUE DU FAUBOURG SAINT HONORE']},
#   'distance': {'value': 1.99, 'unit': 'KM'},
#   'lastUpdate': '2025-10-07T09:03:48'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700029530,
#   'name': 'HOTEL TIVOLI',
#   'hotelId': 'EUPARTIV',
#   'geoCode': {'latitude': 48.87621, 'longitude': 2.29599},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['7 RUE BREY']},
#   'distance': {'value': 2.0, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700158061,
#   'name': 'VILLATHENA 2',
#   'hotelId': 'HSORYAEG',
#   'geoCode': {'latitude': 48.84719, 'longitude': 2.27294},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['5 RUE MIRABEAU']},
#   'distance': {'value': 2.0, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:05'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700061089,
#   'name': 'HTL RESIDENCE FOCH',
#   'hotelId': 'YXPAR662',
#   'geoCode': {'latitude': 48.87407, 'longitude': 2.28119},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['10 RUE MARBEAU']},
#   'distance': {'value': 2.01, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:56'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700057440,
#   'name': 'BEST WESTERN MONTCALM',
#   'hotelId': 'BWPAR126',
#   'geoCode': {'latitude': 48.84081, 'longitude': 2.28722},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['50 AVENUE FELIX FAURE']},
#   'distance': {'value': 2.01, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:17:06'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700132241,
#   'name': 'HELZEAR SAINT-HONORE',
#   'hotelId': 'FGPARHEL',
#   'geoCode': {'latitude': 48.87351, 'longitude': 2.30933},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['164 166 RUE FAUBOURG SAINT HONORE']},
#   'distance': {'value': 2.01, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:43'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700062224,
#   'name': 'HOTEL CENTREVILLE ETOILE',
#   'hotelId': 'UIPAR175',
#   'geoCode': {'latitude': 48.87608, 'longitude': 2.28962},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['6 RUE DES ACACIAS']},
#   'distance': {'value': 2.01, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:11'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 501450466,
#   'name': 'CRAYON ROUGE',
#   'hotelId': 'ACPARF14',
#   'geoCode': {'latitude': 48.87569, 'longitude': 2.28632},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75001',
#    'cityName': 'PARIS',
#    'lines': ['42 RUE CROIX DES PETITS CHAMPS']},
#   'distance': {'value': 2.03, 'unit': 'KM'},
#   'lastUpdate': '2025-10-01T09:00:17'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700045507,
#   'name': 'ALEXANDRINE OPERA',
#   'hotelId': 'ACPARF08',
#   'geoCode': {'latitude': 48.87569, 'longitude': 2.28632},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['10 RUE DE MOSCOU']},
#   'distance': {'value': 2.03, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:09'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700011037,
#   'name': 'PERGOLESE',
#   'hotelId': 'ACPARF07',
#   'geoCode': {'latitude': 48.87569, 'longitude': 2.28632},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['3 RUE PERGOLESE']},
#   'distance': {'value': 2.03, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:57'},
#  {'chainCode': 'HS',
#   'iataCode': 'CDG',
#   'dupeId': 700021908,
#   'name': 'LA REGENCE ETOILE',
#   'hotelId': 'HSCDGAAR',
#   'geoCode': {'latitude': 48.87655, 'longitude': 2.29293},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['AVENUE CARNOT 24']},
#   'distance': {'value': 2.04, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:13'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092135,
#   'name': 'ELYSEE ETOILE HOTEL',
#   'hotelId': 'YXPAR194',
#   'geoCode': {'latitude': 48.8766, 'longitude': 2.2964},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['5 RUE DE L`ETOILE']},
#   'distance': {'value': 2.04, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:55'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700007721,
#   'name': 'ROYAL GARDEN CHAMPS ELYSEES HOTEL',
#   'hotelId': 'UIPAR296',
#   'geoCode': {'latitude': 48.87576, 'longitude': 2.30343},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['218-220 RUE DU FAUBOURG SAINT HONORE']},
#   'distance': {'value': 2.05, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:11'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700092132,
#   'name': 'BELFAST HOTEL PARIS',
#   'hotelId': 'YXPARBEL',
#   'geoCode': {'latitude': 48.87685, 'longitude': 2.29226},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['AV CARNOT 10']},
#   'distance': {'value': 2.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:56'},
#  {'chainCode': 'UZ',
#   'iataCode': 'PAR',
#   'dupeId': 700007094,
#   'name': 'ELYSEES CERAMIC HOTEL',
#   'hotelId': 'UZPARECH',
#   'geoCode': {'latitude': 48.87683, 'longitude': 2.29754},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['34 AVENUE DE WAGRAM']},
#   'distance': {'value': 2.07, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:12'},
#  {'chainCode': 'VP',
#   'iataCode': 'PAR',
#   'dupeId': 502347190,
#   'name': 'LA VILLA MAILLOT & SPA',
#   'hotelId': 'VPPAR045',
#   'geoCode': {'latitude': 48.87557, 'longitude': 2.28365},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'Paris',
#    'lines': ['143 AVENUE DE MALAKOFF']},
#   'distance': {'value': 2.08, 'unit': 'KM'},
#   'lastUpdate': '2025-10-08T09:00:11'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700158034,
#   'name': 'EXCLUSIVE TILSITT ETOILE',
#   'hotelId': 'EUPAR435',
#   'geoCode': {'latitude': 48.87698, 'longitude': 2.29504},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['23 RUE BREY']},
#   'distance': {'value': 2.08, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'LW',
#   'iataCode': 'PAR',
#   'dupeId': 700009325,
#   'name': 'LE BRISTOL PARIS',
#   'hotelId': 'LWPAR012',
#   'geoCode': {'latitude': 48.87161, 'longitude': 2.31455},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['112 RUE DU FAUBOURG ST-HONORE']},
#   'distance': {'value': 2.08, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:46'},
#  {'chainCode': 'BW',
#   'iataCode': 'PAR',
#   'dupeId': 700061683,
#   'name': 'BEST WESTERN STAR CHAMPS ELYSE',
#   'hotelId': 'BWPAR654',
#   'geoCode': {'latitude': 48.8771, 'longitude': 2.29358},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['18 RUE DE LARC DE TRIOMPHE']},
#   'distance': {'value': 2.09, 'unit': 'KM'},
#   'masterChainCode': 'EW',
#   'lastUpdate': '2025-06-03T10:17:38'},
#  {'chainCode': 'BR',
#   'iataCode': 'PAR',
#   'dupeId': 700120570,
#   'name': 'RENAISSANCE ARC DE TRIOMPHE',
#   'hotelId': 'BRPARWGB',
#   'geoCode': {'latitude': 48.87711, 'longitude': 2.29745},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75017',
#    'cityName': 'PARIS',
#    'lines': ['39 AVENUE DE WAGRAM']},
#   'distance': {'value': 2.11, 'unit': 'KM'},
#   'masterChainCode': 'EM',
#   'lastUpdate': '2025-10-06T06:06:52'},
#  {'chainCode': 'YX',
#   'iataCode': 'PAR',
#   'dupeId': 700078995,
#   'name': 'HOTEL D ORSAY',
#   'hotelId': 'YXPAR055',
#   'geoCode': {'latitude': 48.86041, 'longitude': 2.32321},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['93, RUE DE LILLE']},
#   'distance': {'value': 2.11, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:55'},
#  {'chainCode': 'RT',
#   'iataCode': 'PAR',
#   'dupeId': 700048021,
#   'name': 'NOVOTEL PARIS VAUGIRARD MONTP',
#   'hotelId': 'RTPARVGR',
#   'geoCode': {'latitude': 48.83997, 'longitude': 2.30303},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['257 RUE DE VAUGIRARD']},
#   'distance': {'value': 2.12, 'unit': 'KM'},
#   'masterChainCode': 'RT',
#   'lastUpdate': '2025-06-03T10:17:27'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700092062,
#   'name': 'DUC DE SAINT-SIMON',
#   'hotelId': 'ACPAR872',
#   'geoCode': {'latitude': 48.85598, 'longitude': 2.32365},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['14, RUE DE SAINT-SIMON']},
#   'distance': {'value': 2.14, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700076383,
#   'name': 'HOTEL ETOILE RESIDENCE IMPERIALE',
#   'hotelId': 'FGPAR277',
#   'geoCode': {'latitude': 48.87618, 'longitude': 2.2835},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75116',
#    'cityName': 'PARIS',
#    'lines': ['155 AVENUE DE MALAKOFF']},
#   'distance': {'value': 2.15, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:42'},
#  {'chainCode': 'FG',
#   'iataCode': 'PAR',
#   'dupeId': 700076369,
#   'name': 'HOTELHOME PARIS 16',
#   'hotelId': 'FGPARHHM',
#   'geoCode': {'latitude': 48.8506, 'longitude': 2.26745},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75016',
#    'cityName': 'PARIS',
#    'lines': ['36, RUE GEORGE SAND']},
#   'distance': {'value': 2.15, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:43'},
#  {'chainCode': 'UI',
#   'iataCode': 'PAR',
#   'dupeId': 700040012,
#   'name': 'ASTOTEL LE 123 ELYSEES',
#   'hotelId': 'UIPARPHI',
#   'geoCode': {'latitude': 48.87423, 'longitude': 2.31117},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75008',
#    'cityName': 'PARIS',
#    'lines': ['123 RUE DU FAUBOURG ST. HONORE']},
#   'distance': {'value': 2.15, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:01'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700058799,
#   'name': 'EXCELSIOR REPUBLIQUE',
#   'hotelId': 'ACPAR428',
#   'geoCode': {'latitude': 48.83981, 'longitude': 2.28476},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75010',
#    'cityName': 'PARIS',
#    'lines': ['4, RUE DE LANCRY']},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:12'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700010271,
#   'name': 'AMADEUS MON REVE',
#   'hotelId': 'ACPAR420',
#   'geoCode': {'latitude': 48.83981, 'longitude': 2.28476},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['76, AVENUE FELIX FAURE']},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700029531,
#   'name': "HOTEL SQUARE D'ANVERS",
#   'hotelId': 'ACPAR431',
#   'geoCode': {'latitude': 48.83981, 'longitude': 2.28476},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75009',
#    'cityName': 'PARIS',
#    'lines': ["6 PLACE D'ANVERS"]},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:35'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700156318,
#   'name': 'MODERN',
#   'hotelId': 'ACPAR435',
#   'geoCode': {'latitude': 48.83981, 'longitude': 2.28476},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75011',
#    'cityName': 'PARIS',
#    'lines': ['121, RUE DU CHEMIN VERT']},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:00'},
#  {'chainCode': 'AC',
#   'iataCode': 'PAR',
#   'dupeId': 700061451,
#   'name': 'SAINT GERMAIN DES PRES',
#   'hotelId': 'ACPAR429',
#   'geoCode': {'latitude': 48.83981, 'longitude': 2.28476},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75006',
#    'cityName': 'PARIS',
#    'lines': ['36, RUE BONAPART']},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:17:25'},
#  {'chainCode': 'HS',
#   'iataCode': 'ORY',
#   'dupeId': 700092114,
#   'name': 'AVIA SAPHIR MONTPARNASSE',
#   'hotelId': 'HSORYAFE',
#   'geoCode': {'latitude': 48.84304, 'longitude': 2.31317},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75015',
#    'cityName': 'PARIS',
#    'lines': ['181 RUE DE VAUGIRARD']},
#   'distance': {'value': 2.17, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:21:05'},
#  {'chainCode': 'EU',
#   'iataCode': 'PAR',
#   'dupeId': 700025211,
#   'name': 'HOTEL VANEAU SAINT GERMAIN',
#   'hotelId': 'EUPARVSG',
#   'geoCode': {'latitude': 48.84856, 'longitude': 2.32038},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['86 RUE VANEAU']},
#   'distance': {'value': 2.18, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:19:54'},
#  {'chainCode': 'LX',
#   'iataCode': 'PAR',
#   'dupeId': 700005168,
#   'name': 'LE BELLECHASSE SAINT-GERMAIN',
#   'hotelId': 'LXPARBEL',
#   'geoCode': {'latitude': 48.85973, 'longitude': 2.32431},
#   'address': {'countryCode': 'FR',
#    'postalCode': '75007',
#    'cityName': 'PARIS',
#    'lines': ['8 RUE BELLECHASSE']},
#   'distance': {'value': 2.18, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:16:45'}]

# %%
search_hotels_by_area_result2 = tools.search_hotels_by_area.invoke({
    "place_name": "Christ University, Bengaluru",
    # "radius": 3
})
search_hotels_by_area_result2
# Out:
# 🏨 Searching for hotels near (12.9337799, 77.6051611) within 2KM...
# 🏨 Searching for hotels near lat:12.9337799, lon:77.6051611 within a 2KM radius.
# [{'chainCode': 'YX',
#   'iataCode': 'BLR',
#   'dupeId': 700172728,
#   'name': 'DAVANAM SAROVAR PORTICO SUITES',
#   'hotelId': 'YXBLRDSP',
#   'geoCode': {'latitude': 12.92651, 'longitude': 77.61687},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560068',
#    'cityName': 'BENGALURU',
#    'lines': ['DAVANAM PLAZA', 'OPP MADIWALA POLICE STATION, HOSUR MAIN ROAD']},
#   'distance': {'value': 1.5, 'unit': 'KM'},
#   'lastUpdate': '2025-06-03T10:18:45'},
#  {'chainCode': 'OI',
#   'iataCode': 'BLR',
#   'dupeId': 700095230,
#   'name': 'HALCYON BANGALORE',
#   'hotelId': 'OIBLR049',
#   'geoCode': {'latitude': 12.93179, 'longitude': 77.62211},
#   'address': {'countryCode': 'IN',
#    'postalCode': '560047',
#    'cityName': 'Bengaluru',
#    'lines': ['9 DRAFADILA LAYOUT', '4TH BLOCK KORAMANGALA']},
#   'distance': {'value': 1.85, 'unit': 'KM'},
#   'masterChainCode': 'LK',
#   'lastUpdate': '2025-06-03T10:20:11'}]

# %% [markdown]
# ## testing the Agents

# %%
from llm_graph import create_travel_agent
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
load_dotenv()
app  = create_travel_agent()
# Out:
# 🤖 Initializing LangGraph agent with supervisor...
# ✅ LangGraph agent with supervisor initialized successfully.

# %%
result = app.invoke({"messages": [HumanMessage(content="Find me find me flight from Bengaluru, india to kochi, India on 25th october 2025 for 1 adult and 1 child. Also find me hotels in bangalore city.") ]})
print(f"Final Agent Response: {result['messages'][-1].content}")
# Out:
# 🧠 Worker LLM response: content='' additional_kwargs={'function_call': {'name': 'search_hotels_by_city', 'arguments': '{"city_code": "BLR"}'}} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'} id='lc_run--5da14eca-c930-4015-aef7-e17ce5e8a7a8-0' tool_calls=[{'name': 'search_flights', 'args': {'origin': 'BLR', 'destination': 'COK', 'num_adults': 1, 'departure_date': '2025-10-25', 'num_children': 1}, 'id': '3408a85f-7ad2-4b31-94f4-bf71b46f6626', 'type': 'tool_call'}, {'name': 'search_hotels_by_city', 'args': {'city_code': 'BLR'}, 'id': 'c5431f81-d883-41d7-bc97-f27d39ea3256', 'type': 'tool_call'}] usage_metadata={'input_tokens': 661, 'output_tokens': 316, 'total_tokens': 977, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 241}}
# -----------------------------------------
# ✈️ Searching for flights from BLR to COK on 2025-10-25...
#     Adults: 1, Children: 1, Non-stop: True, Max Results: 10
# ✈️  Searching for flights: BLR -> COK on 2025-10-25
# 🏨 Searching for hotels in city: BLR...
# 🏨 Searching for hotels in city: BLR
#     Found 4 flights.
#  flight details: [{'type': 'flight-offer', 'id': '1', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '2', 'at': '2025-10-25T11:00:00'}, 'arrival': {'iataCode': 'COK', 'terminal': '3', 'at': '2025-10-25T12:00:00'}, 'carrierCode': 'AI', 'number': '9451', 'aircraft': {'code': '320'}, 'operating': {'carrierCode': 'IX'}, 'duration': 'PT1H', 'id': '1', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total': '64.88', 'base': '42.00', 'fees': [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amount': '0.00', 'type': 'TICKETING'}], 'grandTotal': '64.88'}, 'pricingOptions': {'fareType': ['PUBLISHED'], 'includedCheckedBagsOnly': False}, 'validatingAirlineCodes': ['AI'], 'travelerPricings': [{'travelerId': '1', 'fareOption': 'STANDARD', 'travelerType': 'ADULT', 'price': {'currency': 'EUR', 'total': '33.49', 'base': '22.00'}, 'fareDetailsBySegment': [{'segmentId': '1', 'cabin': 'ECONOMY', 'fareBasis': 'SL1YXYII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'S', 'includedCheckedBags': {'weight': 15, 'weightUnit': 'KG'}, 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'UPGRADE', 'isChargeable': True, 'amenityType': 'UPGRADES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'FREE CHECKED BAGGAGE ALLOWANCE', 'isChargeable': False, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}]}]}, {'travelerId': '2', 'fareOption': 'STANDARD', 'travelerType': 'CHILD', 'price': {'currency': 'EUR', 'total': '31.39', 'base': '20.00'}, 'fareDetailsBySegment': [{'segmentId': '1', 'cabin': 'ECONOMY', 'fareBasis': 'SL1YXYII', 'brandedFare': 'ECOVALU', 'brandedFareLabel': 'ECO VALUE', 'class': 'S', 'amenities': [{'description': 'PRE RESERVED SEAT ASSIGNMENT', 'isChargeable': False, 'amenityType': 'PRE_RESERVED_SEAT', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'MEAL SERVICES', 'isChargeable': False, 'amenityType': 'MEAL', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'REFUNDABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'CHANGEABLE TICKET', 'isChargeable': True, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'UPGRADE', 'isChargeable': True, 'amenityType': 'UPGRADES', 'amenityProvider': {'name': 'BrandedFare'}}, {'description': 'FREE CHECKED BAGGAGE ALLOWANCE', 'isChargeable': False, 'amenityType': 'BRANDED_FARES', 'amenityProvider': {'name': 'BrandedFare'}}]}]}]}, {'type': 'flight-offer', 'id': '2', 'source': 'GDS', 'instantTicketingRequired': False, 'nonHomogeneous': False, 'oneWay': False, 'isUpsellOffer': False, 'lastTicketingDate': '2025-10-21', 'lastTicketingDateTime': '2025-10-21', 'numberOfBookableSeats': 9, 'itineraries': [{'duration': 'PT1H', 'segments': [{'departure': {'iataCode': 'BLR', 'terminal': '1', 'at': '2025-10-25T15:50:00'}, 'arrival': {'iataCode': 'COK', 'terminal': '3', 'at': '2025-10-25T16:50:00'}, 'carrierCode': 'AI', 'number': '9455', 'aircraft': {'code': '320'}, 'operating': {'carrierCode': 'IX'}, 'duration': 'PT1H', 'id': '2', 'numberOfStops': 0, 'blacklistedInEU': False}]}], 'price': {'currency': 'EUR', 'total' ...
# 🧠 Supervisor LLM final response: content="Here's the flight and hotel information you requested:\n\n## Flights from Bengaluru (BLR) to Kochi (COK) on October 25, 2025 (1 Adult, 1 Child)\n\nHere are the top flight options found:\n\n1.  **Flight Number:** AI 9453 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour 10 minutes\n    *   **Departure:** 2025-10-25, 07:35 from BLR Terminal 1\n    *   **Arrival:** 2025-10-25, 08:45 at COK Terminal 3\n\n2.  **Flight Number:** AI 9451 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 11:00 from BLR Terminal 2\n    *   **Arrival:** 2025-10-25, 12:00 at COK Terminal 3\n\n3.  **Flight Number:** AI 9455 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 15:50 from BLR Terminal 1\n    *   **Arrival:** 2025-10-25, 16:50 at COK Terminal 3\n\n4.  **Flight Number:** AI 9457 (Air India Express)\n    *   **Price:** 132.08 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 21:10 from BLR Terminal 2\n    *   **Arrival:** 2025-10-25, 22:10 at COK Terminal 3\n\n**Recommendation:**\nFor the best value and an early start to your day, I recommend **Flight AI 9453** departing at 07:35 for 64.88 EUR. If you prefer a mid-day flight, **AI 9451** at 11:00 is also a great option at the same price.\n\n---\n\n## Hotels in Bangalore City\n\nHere are some hotels found in Bangalore:\n\n*   **THE CHANCERY PAVILION**\n    *   Address: 135 RESIDENCY ROAD, BANGALORE, IN 560025\n*   **HALCYON BANGALORE**\n    *   Address: 9 DRAFADILA LAYOUT, 4TH BLOCK KORAMANGALA, Bengaluru, IN 560047\n*   **ALOFT BENGALURU CESSNA PARK**\n    *   Address: CESSNA BUSINESS PARK SARJAPUR, KADUBEESANAHALLI BELLANDUR POS, BENGALURU, IN 560103\n*   **LEMON TREE PREMIER ULSOOR LAKE BENGALURU**\n    *   Address: ST JOHNS ROAD, ULSOOR LAKE, BENGALURU, IN 560042\n*   **THE RITZ CARLTON, BANGALORE**\n    *   Address: NUMBER 99, RESIDENCY ROAD BANGALORE, KARNATAKA, 560025\n*   **JW MARRIOTT HOTEL BENGALURU**\n    *   Address: 24/1 VITTAL MALLYA ROAD - BENGALURU, 560001 INDIA\n*   **GINGER BANGALORE WHITEFIELD**\n    *   Address: WHITEFIELD, 128 EPIP PHASE II, BENGALURU, IN 560066\n*   **SHERATON BANGALORE**\n    *   Address: 26 1 DR RAJKUMAR ROAD, MALLESWARAM RAJAJINAGAR, BENGALURU, IN 560055\n*   **THE OBEROI, BANGALORE**\n    *   Address: 37-39 MAHATMA GANDHI ROAD, BANGALORE, IN 560001" additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'} id='lc_run--cc3b1c1a-48c6-4463-ac12-eccd8d6ce90e-0' usage_metadata={'input_tokens': 41819, 'output_tokens': 2130, 'total_tokens': 43949, 'input_token_details': {'cache_read': 40919}, 'output_token_details': {'reasoning': 1135}}
# =========================================
# Final Agent Response: Here's the flight and hotel information you requested:
#
# ## Flights from Bengaluru (BLR) to Kochi (COK) on October 25, 2025 (1 Adult, 1 Child)
#
# Here are the top flight options found:
#
# 1.  **Flight Number:** AI 9453 (Air India Express)
#     *   **Price:** 64.88 EUR
#     *   **Duration:** 1 hour 10 minutes
#     *   **Departure:** 2025-10-25, 07:35 from BLR Terminal 1
#     *   **Arrival:** 2025-10-25, 08:45 at COK Terminal 3
#
# 2.  **Flight Number:** AI 9451 (Air India Express)
#     *   **Price:** 64.88 EUR
#     *   **Duration:** 1 hour
#     *   **Departure:** 2025-10-25, 11:00 from BLR Terminal 2
#     *   **Arrival:** 2025-10-25, 12:00 at COK Terminal 3
#
# 3.  **Flight Number:** AI 9455 (Air India Express)
#     *   **Price:** 64.88 EUR
#     *   **Duration:** 1 hour
#     *   **Departure:** 2025-10-25, 15:50 from BLR Terminal 1
#     *   **Arrival:** 2025-10-25, 16:50 at COK Terminal 3
#
# 4.  **Flight Number:** AI 9457 (Air India Express)
#     *   **Price:** 132.08 EUR
#     *   **Duration:** 1 hour
#     *   **Departure:** 2025-10-25, 21:10 from BLR Terminal 2
#     *   **Arrival:** 2025-10-25, 22:10 at COK Terminal 3
#
# **Recommendation:**
# For the best value and an early start to your day, I recommend **Flight AI 9453** departing at 07:35 for 64.88 EUR. If you prefer a mid-day flight, **AI 9451** at 11:00 is also a great option at the same price.
#
# ---
#
# ## Hotels in Bangalore City
#
# Here are some hotels found in Bangalore:
#
# *   **THE CHANCERY PAVILION**
#     *   Address: 135 RESIDENCY ROAD, BANGALORE, IN 560025
# *   **HALCYON BANGALORE**
#     *   Address: 9 DRAFADILA LAYOUT, 4TH BLOCK KORAMANGALA, Bengaluru, IN 560047
# *   **ALOFT BENGALURU CESSNA PARK**
#     *   Address: CESSNA BUSINESS PARK SARJAPUR, KADUBEESANAHALLI BELLANDUR POS, BENGALURU, IN 560103
# *   **LEMON TREE PREMIER ULSOOR LAKE BENGALURU**
#     *   Address: ST JOHNS ROAD, ULSOOR LAKE, BENGALURU, IN 560042
# *   **THE RITZ CARLTON, BANGALORE**
#     *   Address: NUMBER 99, RESIDENCY ROAD BANGALORE, KARNATAKA, 560025
# *   **JW MARRIOTT HOTEL BENGALURU**
#     *   Address: 24/1 VITTAL MALLYA ROAD - BENGALURU, 560001 INDIA
# *   **GINGER BANGALORE WHITEFIELD**
#     *   Address: WHITEFIELD, 128 EPIP PHASE II, BENGALURU, IN 560066
# *   **SHERATON BANGALORE**
#     *   Address: 26 1 DR RAJKUMAR ROAD, MALLESWARAM RAJAJINAGAR, BENGALURU, IN 560055
# *   **THE OBEROI, BANGALORE**
#     *   Address: 37-39 MAHATMA GANDHI ROAD, BANGALORE, IN 560001

# %%
result
# Out:
# {'messages': [HumanMessage(content='Find me find me flight from Bengaluru, india to kochi, India on 25th october 2025 for 1 adult and 1 child. Also find me hotels in bangalore city.', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels_by_city', 'arguments': '{"city_code": "BLR"}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--5da14eca-c930-4015-aef7-e17ce5e8a7a8-0', tool_calls=[{'name': 'search_flights', 'args': {'origin': 'BLR', 'destination': 'COK', 'num_adults': 1, 'departure_date': '2025-10-25', 'num_children': 1}, 'id': '3408a85f-7ad2-4b31-94f4-bf71b46f6626', 'type': 'tool_call'}, {'name': 'search_hotels_by_city', 'args': {'city_code': 'BLR'}, 'id': 'c5431f81-d883-41d7-bc97-f27d39ea3256', 'type': 'tool_call'}], usage_metadata={'input_tokens': 661, 'output_tokens': 316, 'total_tokens': 977, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 241}}),
#   ToolMessage(content='[{"type": "flight-offer", "id": "1", "source": "GDS", "instantTicketingRequired": false, "nonHomogeneous": false, "oneWay": false, "isUpsellOffer": false, "lastTicketingDate": "2025-10-21", "lastTicketingDateTime": "2025-10-21", "numberOfBookableSeats": 9, "itineraries": [{"duration": "PT1H", "segments": [{"departure": {"iataCode": "BLR", "terminal": "2", "at": "2025-10-25T11:00:00"}, "arrival": {"iataCode": "COK", "terminal": "3", "at": "2025-10-25T12:00:00"}, "carrierCode": "AI", "number": "9451", "aircraft": {"code": "320"}, "operating": {"carrierCode": "IX"}, "duration": "PT1H", "id": "1", "numberOfStops": 0, "blacklistedInEU": false}]}], "price": {"currency": "EUR", "total": "64.88", "base": "42.00", "fees": [{"amount": "0.00", "type": "SUPPLIER"}, {"amount": "0.00", "type": "TICKETING"}], "grandTotal": "64.88"}, "pricingOptions": {"fareType": ["PUBLISHED"], "includedCheckedBagsOnly": false}, "validatingAirlineCodes": ["AI"], "travelerPricings": [{"travelerId": "1", "fareOption": "STANDARD", "travelerType": "ADULT", "price": {"currency": "EUR", "total": "33.49", "base": "22.00"}, "fareDetailsBySegment": [{"segmentId": "1", "cabin": "ECONOMY", "fareBasis": "SL1YXYII", "brandedFare": "ECOVALU", "brandedFareLabel": "ECO VALUE", "class": "S", "includedCheckedBags": {"weight": 15, "weightUnit": "KG"}, "amenities": [{"description": "PRE RESERVED SEAT ASSIGNMENT", "isChargeable": false, "amenityType": "PRE_RESERVED_SEAT", "amenityProvider": {"name": "BrandedFare"}}, {"description": "MEAL SERVICES", "isChargeable": false, "amenityType": "MEAL", "amenityProvider": {"name": "BrandedFare"}}, {"description": "REFUNDABLE TICKET", "isChargeable": true, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "CHANGEABLE TICKET", "isChargeable": true, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "UPGRADE", "isChargeable": true, "amenityType": "UPGRADES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "FREE CHECKED BAGGAGE ALLOWANCE", "isChargeable": false, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}]}]}, {"travelerId": "2", "fareOption": "STANDARD", "travelerType": "CHILD", "price": {"currency": "EUR", "total": "31.39", "base": "20.00"}, "fareDetailsBySegment": [{"segmentId": "1", "cabin": "ECONOMY", "fareBasis": "SL1YXYII", "brandedFare": "ECOVALU", "brandedFareLabel": "ECO VALUE", "class": "S", "amenities": [{"description": "PRE RESERVED SEAT ASSIGNMENT", "isChargeable": false, "amenityType": "PRE_RESERVED_SEAT", "amenityProvider": {"name": "BrandedFare"}}, {"description": "MEAL SERVICES", "isChargeable": false, "amenityType": "MEAL", "amenityProvider": {"name": "BrandedFare"}}, {"description": "REFUNDABLE TICKET", "isChargeable": true, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "CHANGEABLE TICKET", "isChargeable": true, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "UPGRADE", "isChargeable": true, "amenityType": "UPGRADES", "amenityProvider": {"name": "BrandedFare"}}, {"description": "FREE CHECKED BAGGAGE ALLOWANCE", "isChargeable": false, "amenityType": "BRANDED_FARES", "amenityProvider": {"name": "BrandedFare"}}]}]}]}, {"type": "flight-offer", "id": "2", "source": "GDS", "instantTicketingRequired": false, "nonHomogeneous": false, "oneWay": false, "isUpsellOffer": false, "lastTicketingDate": "2025-10-21", "lastTicketingDateTime": "2025-10-21", "numberOfBookableSeats": 9, "itineraries": [{"duration": "PT1H", "segments": [{"departure": {"iataCode": "BLR", "terminal": "1", "at": "2025-10-25T15:50:00"}, "arrival": {"iataCode": "COK", "terminal": "3", "at": "2025-10-25T16:50:00"}, "carrierCode": "AI", "number": "9455", "aircraft": {"code": "320"}, "operating": {"carrierCode": "IX"}, "duration": "PT1H", "id": "2", "numberOfStops": 0, "blacklistedInEU": false}]}], "price": {"currency": "EUR", " ...
#   ToolMessage(content='[{"chainCode": "RT", "iataCode": "BLR", "dupeId": 502322423, "name": "VEE TEST NRT PROPERTTT", "hotelId": "RTBLR444", "geoCode": {"latitude": 40.41669, "longitude": -3.70035}, "address": {"countryCode": "ES", "cityName": "MADRID", "lines": ["LEFISTON STREET"]}, "masterChainCode": "RT", "lastUpdate": "2025-06-03T10:17:18"}, {"chainCode": "WV", "iataCode": "BLR", "dupeId": 700150828, "name": "THE CHANCERY PAVILION", "hotelId": "WVBLR907", "geoCode": {"latitude": 12.96838, "longitude": 77.60101}, "address": {"countryCode": "IN", "postalCode": "560025", "cityName": "BANGALORE", "lines": ["135 RESIDENCY ROAD"]}, "masterChainCode": "TC", "lastUpdate": "2025-06-03T10:18:08"}, {"chainCode": "HN", "iataCode": "BLR", "dupeId": 502346769, "name": "HOTEL MSD", "hotelId": "HNBLRLIA", "geoCode": {"latitude": 12.95388, "longitude": 77.68965}, "address": {"countryCode": "IN", "postalCode": "560037", "stateCode": "KA", "cityName": "Bengaluru", "lines": ["BELLANDUR"]}, "lastUpdate": "2025-10-07T09:03:18"}, {"chainCode": "OI", "iataCode": "BLR", "dupeId": 700095230, "name": "HALCYON BANGALORE", "hotelId": "OIBLR049", "geoCode": {"latitude": 12.93179, "longitude": 77.62211}, "address": {"countryCode": "IN", "postalCode": "560047", "cityName": "Bengaluru", "lines": ["9 DRAFADILA LAYOUT", "4TH BLOCK KORAMANGALA"]}, "masterChainCode": "LK", "lastUpdate": "2025-06-03T10:20:11"}, {"chainCode": "AL", "iataCode": "BLR", "dupeId": 700211496, "name": "ALOFT BENGALURU CESSNA PARK", "hotelId": "ALBLR545", "geoCode": {"latitude": 12.93439, "longitude": 77.69448}, "address": {"countryCode": "IN", "postalCode": "560103", "cityName": "BENGALURU", "lines": ["CESSNA BUSINESS PARK SARJAPUR", "KADUBEESANAHALLI BELLANDUR POS"]}, "masterChainCode": "EM", "lastUpdate": "2025-08-04T06:06:07"}, {"chainCode": "HS", "iataCode": "BLR", "dupeId": 502196184, "name": "TEST PROPERTY FOR DXM", "hotelId": "HSBLR674", "geoCode": {"latitude": 12.96685, "longitude": 77.58741}, "address": {"countryCode": "IN", "stateCode": "KA", "cityName": "BENGALURU", "lines": ["LEFISTON STREET"]}, "lastUpdate": "2025-06-03T10:17:52"}, {"chainCode": "SX", "iataCode": "BLR", "dupeId": 700153995, "name": "LEMON TREE PREMIER ULSOOR LAKE BENGALURU", "hotelId": "SXBLRLTH", "geoCode": {"latitude": 12.98655, "longitude": 77.61584}, "address": {"countryCode": "IN", "postalCode": "560042", "cityName": "BENGALURU", "lines": ["ST JOHNS ROAD", "ULSOOR LAKE"]}, "lastUpdate": "2025-06-03T10:17:36"}, {"chainCode": "VP", "iataCode": "BLR", "dupeId": 502346933, "name": "TEST HOTEL FOR SYNXIS", "hotelId": "VPBLR62W", "geoCode": {"latitude": 12.99754, "longitude": 77.55022}, "address": {"countryCode": "IN", "postalCode": "560011", "stateCode": "KA", "cityName": "Bengaluru", "lines": ["WEST OF CORD ROAD"]}, "lastUpdate": "2025-10-07T09:03:48"}, {"chainCode": "HN", "iataCode": "BLR", "dupeId": 502346834, "name": "TEST PROPERTY BLR", "hotelId": "HNBLR457", "geoCode": {"latitude": 45.36, "longitude": 56.39}, "address": {"countryCode": "IN", "postalCode": "56008", "stateCode": "KA", "cityName": "Bengaluru", "lines": ["TEST"]}, "lastUpdate": "2025-08-12T10:14:22"}, {"chainCode": "OI", "iataCode": "BLR", "dupeId": 502347289, "name": "LK PENTEST PROPERTY", "hotelId": "OIBLRWRM", "geoCode": {"latitude": 13.01259, "longitude": 77.66535}, "address": {"countryCode": "IN", "postalCode": "560016", "stateCode": "KA", "cityName": "Bengaluru", "lines": ["SOME HOTEL IN INDIA"]}, "masterChainCode": "LK", "lastUpdate": "2025-10-07T09:03:04"}, {"chainCode": "TA", "iataCode": "BLR", "dupeId": 700155158, "name": "PREMIER INN BANGALORE WHITEFIELD", "hotelId": "TABLR488", "geoCode": {"latitude": 12.98155, "longitude": 77.70878}, "address": {"countryCode": "IN", "postalCode": "560066", "cityName": "BENGALURU", "lines": ["3A1, BROOKFIELD MAIN ROAD", "OPP.IFB CAMPUS, WHITEFIELD"]}, "lastUpdate": "2025-06-03T10:17:46"}, {"chainCode": "UZ", "iataCode": "BLR", "dupeId": 700095271, "name": "SHILTON ROYALE", "hotelId": "UZBLR ...
#   AIMessage(content="Here's the flight and hotel information you requested:\n\n## Flights from Bengaluru (BLR) to Kochi (COK) on October 25, 2025 (1 Adult, 1 Child)\n\nHere are the top flight options found:\n\n1.  **Flight Number:** AI 9453 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour 10 minutes\n    *   **Departure:** 2025-10-25, 07:35 from BLR Terminal 1\n    *   **Arrival:** 2025-10-25, 08:45 at COK Terminal 3\n\n2.  **Flight Number:** AI 9451 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 11:00 from BLR Terminal 2\n    *   **Arrival:** 2025-10-25, 12:00 at COK Terminal 3\n\n3.  **Flight Number:** AI 9455 (Air India Express)\n    *   **Price:** 64.88 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 15:50 from BLR Terminal 1\n    *   **Arrival:** 2025-10-25, 16:50 at COK Terminal 3\n\n4.  **Flight Number:** AI 9457 (Air India Express)\n    *   **Price:** 132.08 EUR\n    *   **Duration:** 1 hour\n    *   **Departure:** 2025-10-25, 21:10 from BLR Terminal 2\n    *   **Arrival:** 2025-10-25, 22:10 at COK Terminal 3\n\n**Recommendation:**\nFor the best value and an early start to your day, I recommend **Flight AI 9453** departing at 07:35 for 64.88 EUR. If you prefer a mid-day flight, **AI 9451** at 11:00 is also a great option at the same price.\n\n---\n\n## Hotels in Bangalore City\n\nHere are some hotels found in Bangalore:\n\n*   **THE CHANCERY PAVILION**\n    *   Address: 135 RESIDENCY ROAD, BANGALORE, IN 560025\n*   **HALCYON BANGALORE**\n    *   Address: 9 DRAFADILA LAYOUT, 4TH BLOCK KORAMANGALA, Bengaluru, IN 560047\n*   **ALOFT BENGALURU CESSNA PARK**\n    *   Address: CESSNA BUSINESS PARK SARJAPUR, KADUBEESANAHALLI BELLANDUR POS, BENGALURU, IN 560103\n*   **LEMON TREE PREMIER ULSOOR LAKE BENGALURU**\n    *   Address: ST JOHNS ROAD, ULSOOR LAKE, BENGALURU, IN 560042\n*   **THE RITZ CARLTON, BANGALORE**\n    *   Address: NUMBER 99, RESIDENCY ROAD BANGALORE, KARNATAKA, 560025\n*   **JW MARRIOTT HOTEL BENGALURU**\n    *   Address: 24/1 VITTAL MALLYA ROAD - BENGALURU, 560001 INDIA\n*   **GINGER BANGALORE WHITEFIELD**\n    *   Address: WHITEFIELD, 128 EPIP PHASE II, BENGALURU, IN 560066\n*   **SHERATON BANGALORE**\n    *   Address: 26 1 DR RAJKUMAR ROAD, MALLESWARAM RAJAJINAGAR, BENGALURU, IN 560055\n*   **THE OBEROI, BANGALORE**\n    *   Address: 37-39 MAHATMA GANDHI ROAD, BANGALORE, IN 560001", additional_kwargs={}, response_metadata={})]}

# %% [markdown]
# ## Image of the Graph

# %%
from langchain_core.messages import AIMessage
reply = AIMessage(content="Hi! How can I help you with your travel plans today?")
type(reply.content)
# Out:
# str
